# %%
import torch
import matplotlib.pyplot as plt
import numpy as np
import torch.nn.functional as F
from torch import nn
from torchvision import datasets, transforms
from timeit import default_timer as timer
plt.style.use('ggplot')

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
transform_train = transforms.Compose([transforms.Resize((32,32)),
                                      transforms.RandomHorizontalFlip(),
                                      transforms.RandomRotation(10),
                                      transforms.RandomAffine(0, shear=10, scale=(0.8,1.2)),
                                      transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2),
                                      transforms.ToTensor(),
                                      transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
                               ])


transform = transforms.Compose([transforms.Resize((32,32)),
                               transforms.ToTensor(),
                               transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
                               ])
training_dataset = datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_train)
validation_dataset = datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)

training_loader = torch.utils.data.DataLoader(training_dataset, batch_size=100, shuffle=True)
validation_loader = torch.utils.data.DataLoader(validation_dataset, batch_size = 100, shuffle=False)
# Out:
# 0it [00:00, ?it/s]
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
#  99%|█████████▉| 169631744/170498071 [00:17<00:00, 11238163.00it/s]
# Files already downloaded and verified

# %%
def im_convert(tensor):
    image = tensor.cpu().clone().detach().numpy()
    image = image.transpose(1, 2, 0)
    image = image * np.array((0.5, 0.5, 0.5)) + np.array((0.5, 0.5, 0.5))
    image = image.clip(0, 1)
    return image

# %%
classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
dataiter = iter(training_loader)
images, labels = dataiter.next()
fig = plt.figure(figsize=(25, 4))

for idx in np.arange(20):
    ax = fig.add_subplot(2, 10, idx+1, xticks=[], yticks=[])
    plt.imshow(im_convert(images[idx]))
    ax.set_title(classes[labels[idx].item()])

# %% [markdown]
# # Activation Func : ReLU

# %%
class Neural_Net(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 16, 3, 1, padding=1)
        # (input channel, output feature map, kernal size, stride, padding)
        self.conv2 = nn.Conv2d(16, 32, 3, 1, padding=1)
        self.conv3 = nn.Conv2d(32, 64, 3, 1, padding=1)
        self.fc1 = nn.Linear(4*4*64, 500)
#         self.dropout1 = nn.Dropout(0.5)
        self.fc2 = nn.Linear(500, 10)
    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.max_pool2d(x, 2, 2)
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2, 2)
        x = F.relu(self.conv3(x))
        x = F.max_pool2d(x, 2, 2)
        x = x.view(-1, 4*4*64)
        x = F.relu(self.fc1(x))
#         x = self.dropout1(x)
        x = self.fc2(x)
        return x

# %%
model = Neural_Net().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr = 0.001)
model
# Out:
# Neural_Net(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (fc1): Linear(in_features=1024, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
# )

# %%
epochs = 10
running_loss_history = []
running_corrects_history = []
val_running_loss_history = []
val_running_corrects_history = []

for e in range(epochs):
    
    running_loss = 0.0
    running_corrects = 0.0
    val_running_loss = 0.0
    val_running_corrects = 0.0
  
    for inputs, labels in training_loader:
    
      start = torch.cuda.Event(enable_timing=True)
      end = torch.cuda.Event(enable_timing=True)


      start.record()
      inputs = inputs.to(device)
      labels = labels.to(device)
      outputs = model(inputs)
      loss = criterion(outputs, labels)

      optimizer.zero_grad()
      loss.backward()
      optimizer.step()

      _, preds = torch.max(outputs, 1)
      running_loss += loss.item()
      running_corrects += torch.sum(preds == labels.data)
      

    else:
      with torch.no_grad():
        for val_inputs, val_labels in validation_loader:
            val_inputs = val_inputs.to(device)
            val_labels = val_labels.to(device)
            val_outputs = model(val_inputs)
            val_loss = criterion(val_outputs, val_labels)

            _, val_preds = torch.max(val_outputs, 1)
            val_running_loss += val_loss.item()
            val_running_corrects += torch.sum(val_preds == val_labels.data)
      
    end.record()
    torch.cuda.synchronize()
    epoch_loss = running_loss/len(training_loader)
    epoch_acc = running_corrects.float()/ len(training_loader)
    running_loss_history.append(epoch_loss)
    running_corrects_history.append(epoch_acc)

    val_epoch_loss = val_running_loss/len(validation_loader)
    val_epoch_acc = val_running_corrects.float()/ len(validation_loader)
    val_running_loss_history.append(val_epoch_loss)
    val_running_corrects_history.append(val_epoch_acc)
    print('epoch :', (e+1))
    print('training loss: {:.4f}, acc {:.4f} '.format(epoch_loss, epoch_acc.item()))
    print('validation loss: {:.4f}, validation acc {:.4f} '.format(val_epoch_loss, val_epoch_acc.item()))
    print('estimated time:', start.elapsed_time(end), "ms")
# Out:
# epoch : 1
# training loss: 1.6447, acc 40.0620
# validation loss: 1.3415, validation acc 51.2900
# estimated time: 1742.4117431640625 ms
# epoch : 2
# training loss: 1.3307, acc 52.1180
# validation loss: 1.1651, validation acc 58.5600
# estimated time: 1720.836181640625 ms
# epoch : 3
# training loss: 1.1731, acc 58.0600
# validation loss: 1.0285, validation acc 63.4700
# estimated time: 1745.3465576171875 ms
# epoch : 4
# training loss: 1.0681, acc 61.9720
# validation loss: 0.9783, validation acc 65.3600
# estimated time: 1737.933349609375 ms
# epoch : 5
# training loss: 0.9959, acc 64.9760
# validation loss: 0.8771, validation acc 69.1900
# estimated time: 1791.3944091796875 ms
# epoch : 6
# training loss: 0.9386, acc 66.7540
# validation loss: 0.8519, validation acc 69.5800
# estimated time: 1761.183837890625 ms
# epoch : 7
# training loss: 0.8952, acc 68.3060
# validation loss: 0.8147, validation acc 71.8000
# estimated time: 1722.10205078125 ms
# epoch : 8
# training loss: 0.8544, acc 69.9820
# validation loss: 0.7806, validation acc 72.7100
# estimated time: 1730.7396240234375 ms
# epoch : 9
# training loss: 0.8211, acc 71.0800
# validation loss: 0.7490, validation acc 73.8500
# estimated time: 1739.936767578125 ms
# epoch : 10
# training loss: 0.7912, acc 72.0820
# validation loss: 0.7298, validation acc 74.5500
# estimated time: 1767.45166015625 ms

# %%
plt.plot(running_loss_history, label='training loss')
plt.plot(val_running_loss_history, label='validation loss')
plt.legend()

# %%
plt.plot(running_corrects_history, label='training accuracy')
plt.plot(val_running_corrects_history, label='validation accuracy')
plt.legend()

# %% [markdown]
# # Weight initialization - Xavior

# %%
class Neural_Net(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 16, 3, 1, padding=1)
        nn.init.xavier_uniform_(self.conv1.weight)
        self.conv2 = nn.Conv2d(16, 32, 3, 1, padding=1)
        nn.init.xavier_uniform_(self.conv2.weight)
        self.conv3 = nn.Conv2d(32, 64, 3, 1, padding=1)
        nn.init.xavier_uniform_(self.conv2.weight)
        self.fc1 = nn.Linear(4*4*64, 500)
        nn.init.xavier_uniform_(self.fc1.weight)
#         self.dropout1 = nn.Dropout(0.5)
        self.fc2 = nn.Linear(500, 10)
        nn.init.xavier_uniform_(self.fc2.weight)
    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.max_pool2d(x, 2, 2)
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2, 2)
        x = F.relu(self.conv3(x))
        x = F.max_pool2d(x, 2, 2)
        x = x.view(-1, 4*4*64)
        x = F.relu(self.fc1(x))
#         x = self.dropout1(x)
        x = self.fc2(x)
        return x

# %%
model = Neural_Net().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr = 0.001)
model
# Out:
# Neural_Net(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (fc1): Linear(in_features=1024, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
# )

# %%
epochs = 10
running_loss_history = []
running_corrects_history = []
val_running_loss_history = []
val_running_corrects_history = []

for e in range(epochs):
    
    running_loss = 0.0
    running_corrects = 0.0
    val_running_loss = 0.0
    val_running_corrects = 0.0
  
    for inputs, labels in training_loader:
    
      start = torch.cuda.Event(enable_timing=True)
      end = torch.cuda.Event(enable_timing=True)


      start.record()
      inputs = inputs.to(device)
      labels = labels.to(device)
      outputs = model(inputs)
      loss = criterion(outputs, labels)

      optimizer.zero_grad()
      loss.backward()
      optimizer.step()

      _, preds = torch.max(outputs, 1)
      running_loss += loss.item()
      running_corrects += torch.sum(preds == labels.data)
      

    else:
      with torch.no_grad():
        for val_inputs, val_labels in validation_loader:
            val_inputs = val_inputs.to(device)
            val_labels = val_labels.to(device)
            val_outputs = model(val_inputs)
            val_loss = criterion(val_outputs, val_labels)

            _, val_preds = torch.max(val_outputs, 1)
            val_running_loss += val_loss.item()
            val_running_corrects += torch.sum(val_preds == val_labels.data)
      
    end.record()
    torch.cuda.synchronize()
    epoch_loss = running_loss/len(training_loader)
    epoch_acc = running_corrects.float()/ len(training_loader)
    running_loss_history.append(epoch_loss)
    running_corrects_history.append(epoch_acc)

    val_epoch_loss = val_running_loss/len(validation_loader)
    val_epoch_acc = val_running_corrects.float()/ len(validation_loader)
    val_running_loss_history.append(val_epoch_loss)
    val_running_corrects_history.append(val_epoch_acc)
    print('epoch :', (e+1))
    print('training loss: {:.4f}, acc {:.4f} '.format(epoch_loss, epoch_acc.item()))
    print('validation loss: {:.4f}, validation acc {:.4f} '.format(val_epoch_loss, val_epoch_acc.item()))
    print('estimated time:', start.elapsed_time(end), "ms")
# Out:
# epoch : 1
# training loss: 1.5811, acc 43.0600
# validation loss: 1.2638, validation acc 54.2500
# estimated time: 1834.1903076171875 ms
# epoch : 2
# training loss: 1.2714, acc 54.7800
# validation loss: 1.0911, validation acc 61.5200
# estimated time: 2152.0712890625 ms
# epoch : 3
# training loss: 1.1274, acc 59.7560
# validation loss: 0.9886, validation acc 65.5400
# estimated time: 1804.3516845703125 ms
# epoch : 4
# training loss: 1.0384, acc 63.1160
# validation loss: 0.9565, validation acc 66.1400
# estimated time: 1797.57666015625 ms
# epoch : 5
# training loss: 0.9788, acc 65.5300
# validation loss: 0.8958, validation acc 68.4500
# estimated time: 1800.916259765625 ms
# epoch : 6
# training loss: 0.9210, acc 67.6240
# validation loss: 0.8432, validation acc 70.4100
# estimated time: 1800.0997314453125 ms
# epoch : 7
# training loss: 0.8766, acc 69.2180
# validation loss: 0.7846, validation acc 72.7400
# estimated time: 1810.6751708984375 ms
# epoch : 8
# training loss: 0.8345, acc 70.6200
# validation loss: 0.8048, validation acc 72.0800
# estimated time: 1785.034423828125 ms
# epoch : 9
# training loss: 0.8125, acc 71.4180
# validation loss: 0.7686, validation acc 72.9800
# estimated time: 1784.10498046875 ms
# epoch : 10
# training loss: 0.7824, acc 72.5000
# validation loss: 0.7427, validation acc 73.7400
# estimated time: 1779.644775390625 ms

# %%
plt.plot(running_loss_history, label='training loss')
plt.plot(val_running_loss_history, label='validation loss')
plt.legend()

# %%
plt.plot(running_corrects_history, label='training accuracy')
plt.plot(val_running_corrects_history, label='validation accuracy')
plt.legend()

# %% [markdown]
# # Batch Normalization

# %%
class Neural_Net(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 16, 3, 1, padding=1)
        # (input channel, output feature map, kernal size, stride, padding)
        self.conv2 = nn.Conv2d(16, 32, 3, 1, padding=1)
        self.conv2_bn = nn.BatchNorm2d(32)
        self.conv3 = nn.Conv2d(32, 64, 3, 1, padding=1)
        self.conv3_bn = nn.BatchNorm2d(64)
        self.fc1 = nn.Linear(4*4*64, 500)
        self.fc1_bn = nn.BatchNorm1d(500)
#         self.dropout1 = nn.Dropout(0.5)
        self.fc2 = nn.Linear(500, 10)
    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.max_pool2d(x, 2, 2)
        x = F.relu(self.conv2_bn(self.conv2(x)))
        x = F.max_pool2d(x, 2, 2)
        x = F.relu(self.conv3_bn(self.conv3(x)))
        x = F.max_pool2d(x, 2, 2)
        x = x.view(-1, 4*4*64)
        x = F.relu(self.fc1_bn(self.fc1(x)))
#         x = self.dropout1(x)
        x = self.fc2(x)
        return x

# %%
model = Neural_Net().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr = 0.001)
model
# Out:
# Neural_Net(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2_bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3_bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Linear(in_features=1024, out_features=500, bias=True)
#   (fc1_bn): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
# )

# %%
epochs = 10
running_loss_history = []
running_corrects_history = []
val_running_loss_history = []
val_running_corrects_history = []

for e in range(epochs):
    
    running_loss = 0.0
    running_corrects = 0.0
    val_running_loss = 0.0
    val_running_corrects = 0.0
  
    for inputs, labels in training_loader:
    
      start = torch.cuda.Event(enable_timing=True)
      end = torch.cuda.Event(enable_timing=True)


      start.record()
      inputs = inputs.to(device)
      labels = labels.to(device)
      outputs = model(inputs)
      loss = criterion(outputs, labels)

      optimizer.zero_grad()
      loss.backward()
      optimizer.step()

      _, preds = torch.max(outputs, 1)
      running_loss += loss.item()
      running_corrects += torch.sum(preds == labels.data)
      

    else:
      with torch.no_grad():
        for val_inputs, val_labels in validation_loader:
            val_inputs = val_inputs.to(device)
            val_labels = val_labels.to(device)
            val_outputs = model(val_inputs)
            val_loss = criterion(val_outputs, val_labels)

            _, val_preds = torch.max(val_outputs, 1)
            val_running_loss += val_loss.item()
            val_running_corrects += torch.sum(val_preds == val_labels.data)
      
    end.record()
    torch.cuda.synchronize()
    epoch_loss = running_loss/len(training_loader)
    epoch_acc = running_corrects.float()/ len(training_loader)
    running_loss_history.append(epoch_loss)
    running_corrects_history.append(epoch_acc)

    val_epoch_loss = val_running_loss/len(validation_loader)
    val_epoch_acc = val_running_corrects.float()/ len(validation_loader)
    val_running_loss_history.append(val_epoch_loss)
    val_running_corrects_history.append(val_epoch_acc)
    print('epoch :', (e+1))
    print('training loss: {:.4f}, acc {:.4f} '.format(epoch_loss, epoch_acc.item()))
    print('validation loss: {:.4f}, validation acc {:.4f} '.format(val_epoch_loss, val_epoch_acc.item()))
    print('estimated time:', start.elapsed_time(end), "ms")
# Out:
# epoch : 1
# training loss: 1.3675, acc 50.8560
# validation loss: 1.0403, validation acc 62.7500
# estimated time: 1831.4873046875 ms
# epoch : 2
# training loss: 1.0594, acc 62.3680
# validation loss: 0.9142, validation acc 67.6500
# estimated time: 1832.3233642578125 ms
# epoch : 3
# training loss: 0.9384, acc 66.9440
# validation loss: 0.8001, validation acc 71.6700
# estimated time: 1834.485595703125 ms
# epoch : 4
# training loss: 0.8612, acc 69.6920
# validation loss: 0.7942, validation acc 72.0200
# estimated time: 2164.497314453125 ms
# epoch : 5
# training loss: 0.8092, acc 71.4960
# validation loss: 0.7257, validation acc 74.9700
# estimated time: 1848.8751220703125 ms
# epoch : 6
# training loss: 0.7638, acc 73.4880
# validation loss: 0.7049, validation acc 75.3600
# estimated time: 1848.29248046875 ms
# epoch : 7
# training loss: 0.7298, acc 74.4280
# validation loss: 0.6769, validation acc 76.4600
# estimated time: 2203.21923828125 ms
# epoch : 8
# training loss: 0.6932, acc 75.7780
# validation loss: 0.6693, validation acc 76.1000
# estimated time: 1824.717041015625 ms
# epoch : 9
# training loss: 0.6733, acc 76.4020
# validation loss: 0.6518, validation acc 77.0700
# estimated time: 1784.59716796875 ms
# epoch : 10
# training loss: 0.6508, acc 77.1640
# validation loss: 0.6432, validation acc 77.7000
# estimated time: 1779.6873779296875 ms

# %%
plt.plot(running_loss_history, label='training loss')
plt.plot(val_running_loss_history, label='validation loss')
plt.legend()

# %%
plt.plot(running_corrects_history, label='training accuracy')
plt.plot(val_running_corrects_history, label='validation accuracy')
plt.legend()
