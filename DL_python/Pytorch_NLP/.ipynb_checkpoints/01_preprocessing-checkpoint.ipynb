# %% [markdown]
# # Common Task in NLP
#
# - text 요약
# - text classification
# - Language modeling
# - speech recognition / correction
# - translation
# - chatbot 등등
#
# ### pytorch가 좋은 이유
#
# - 진입장벽이 상대적으로 낮고 python-like 형태.
# - graph creation이 쉬운 편. (nlp의 경우 dynamic computation graph가 중요하다고 함)
# - 파이썬과 유사하기에 디버깅이 쉬움
# - document
# - device configuration (cpu, gpu 변환)
# - data loading. 데이터 로딩을 위한 api 사용이 쉬운 편이며 parallelized.
# - extension
# - community
# - interoperability.
# - deployment. (production ready platform)
#
# ### projects
# - sentiment analyzer
# - Neural translation machine
#
# 감성분석 {
#     - text classification problem
#     - ouptput class of positive / negative sentiments
#     - IMBD movie reviews as datasets.
#     - data cleaning / preprocess with NLTK, spaCy
#     - 원 핫 인코딩은 너무 많은 dimension 생성 때문에 예측 정확도가 떨어지므로, word embedding using Gensim.
#     - recurrent NN 쓸 예정.
#     - improve model by LSTM
# }
#
# Neural translation machine {
#     - 언어 받아서 다른 언어로 번역하는 것. 구글번역기가 대표적. 단어 / 문장 단위 mapping이 아니라 NN 사용한 것
#     - sequence to sequence model 사용 예정
#     - 영어 -> 프랑스어 변환.
# }

# %%
import nltk
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/inspirit941/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import spacy
# !python -m spacy download en

# %%
from nltk.corpus import stopwords
stop_words = stopwords.words('english')

# %%
nlp = spacy.load('en')

# %% [markdown]
# 영화 리뷰 텍스트.

# %%
from nltk.tokenize import sent_tokenize
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/inspirit941/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
sent_tokenize('hello world, we are trying out nltk. this would be awesome.')
# 일반적인 경우 문장 단위로 끊는다. 하지만 이제 우리가 보려는 영화 리뷰는 \n 단위로 끊어야 한다
# 따라서 예제에 사용할 데이터는 파이썬 내장함수를 사용해 읽어들이자
# Out:
# ['hello world, we are trying out nltk.', 'this would be awesome.']

# %%
reviewFile = open("./Hands-on-NLP-with-PyTorch-master/data/reviews.txt",'r')
reviews = list(map(lambda x: x[:-1], reviewFile.readlines()))
reviewFile.close()

labelFile = open("./Hands-on-NLP-with-PyTorch-master/data/labels.txt",'r')
labels = list(map(lambda x:x[:-1], labelFile.readlines()))
labelFile.close()

# %%
print(len(reviews), len(labels))
set(labels) # 긍정 / 부정 딱 두 개 있다.
# Out:
# 25000 25000
# {'negative', 'positive'}

# %%
reviews[0]
# Out:
# 'bromwell high is a cartoon comedy . it ran at the same time as some other programs about school life  such as  teachers  . my   years in the teaching profession lead me to believe that bromwell high  s satire is much closer to reality than is  teachers  . the scramble to survive financially  the insightful students who can see right through their pathetic teachers  pomp  the pettiness of the whole situation  all remind me of the schools i knew and their students . when i saw the episode in which a student repeatedly tried to burn down the school  i immediately recalled . . . . . . . . . at . . . . . . . . . . high . a classic line inspector i  m here to sack one of your teachers . student welcome to bromwell high . i expect that many adults of my age think that bromwell high is far fetched . what a pity that it isn  t   '

# %%
nltk.word_tokenize(reviews[0])
# 그냥 돌리면, 마찬가지로 '필요없는 분류'가 많아진다.
# 고민해야 할 지점. -> 어떤 형태의 token이 의미가 있을 것인가.
# 만약 문장 의미 위주라면 말줄임표를 의미하는 점 여러개는 필요없지만, emotion 분석에는 의미 있을지도 모른다.
# 필요한 걸 regex로 분류해줘야 한다
# Out:
# ['bromwell',
#  'high',
#  'is',
#  'a',
#  'cartoon',
#  'comedy',
#  '.',
#  'it',
#  'ran',
#  'at',
#  'the',
#  'same',
#  'time',
#  'as',
#  'some',
#  'other',
#  'programs',
#  'about',
#  'school',
#  'life',
#  'such',
#  'as',
#  'teachers',
#  '.',
#  'my',
#  'years',
#  'in',
#  'the',
#  'teaching',
#  'profession',
#  'lead',
#  'me',
#  'to',
#  'believe',
#  'that',
#  'bromwell',
#  'high',
#  's',
#  'satire',
#  'is',
#  'much',
#  'closer',
#  'to',
#  'reality',
#  'than',
#  'is',
#  'teachers',
#  '.',
#  'the',
#  'scramble',
#  'to',
#  'survive',
#  'financially',
#  'the',
#  'insightful',
#  'students',
#  'who',
#  'can',
#  'see',
#  'right',
#  'through',
#  'their',
#  'pathetic',
#  'teachers',
#  'pomp',
#  'the',
#  'pettiness',
#  'of',
#  'the',
#  'whole',
#  'situation',
#  'all',
#  'remind',
#  'me',
#  'of',
#  'the',
#  'schools',
#  'i',
#  'knew',
#  'and',
#  'their',
#  'students',
#  '.',
#  'when',
#  'i',
#  'saw',
#  'the',
#  'episode',
#  'in',
#  'which',
#  'a',
#  'student',
#  'repeatedly',
#  'tried',
#  'to',
#  'burn',
#  'down',
#  'the',
#  'school',
#  'i',
#  'immediately',
#  'recalled',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  'at',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  'high',
#  '.',
#  'a',
#  'classic',
#  'line',
#  'inspector',
#  'i',
#  'm',
#  'here',
#  'to',
#  'sack',
#  'one',
#  'of',
#  'your',
#  'teachers',
#  '.',
#  'student',
#  'welcome',
#  'to',
#  'bromwell',
#  'high',
#  '.',
#  'i',
#  'expect',
#  'that',
#  'many',
#  'adults',
#  'of',
#  'my',
#  'age',
#  'think',
#  'that',
#  'bromwell',
#  'high',
#  'is',
#  'far',
#  'fetched',
#  '.',
#  'what',
#  'a',
#  'pity',
#  'that',
#  'it',
#  'isn',
#  't']

# %%
from nltk.tokenize import RegexpTokenizer
tokenizer = RegexpTokenizer("\w+")

# %%
tokenizer.tokenize("I didn't like the movie.")
# didn't가 두 개로 나뉘는 문제가 발생했다. 이 부분을 수정해 주면
# Out:
# ['I', 'didn', 't', 'like', 'the', 'movie']

# %%
tokenizer = RegexpTokenizer("\w+\'?\w+|\w+")
tokenizer.tokenize("I didn't like the movie.")
# 이 원칙으로 다시 리뷰를 돌려보자
# Out:
# ['I', "didn't", 'like', 'the', 'movie']

# %%
tokenizer.tokenize(reviews[0])
# Out:
# ['bromwell',
#  'high',
#  'is',
#  'a',
#  'cartoon',
#  'comedy',
#  'it',
#  'ran',
#  'at',
#  'the',
#  'same',
#  'time',
#  'as',
#  'some',
#  'other',
#  'programs',
#  'about',
#  'school',
#  'life',
#  'such',
#  'as',
#  'teachers',
#  'my',
#  'years',
#  'in',
#  'the',
#  'teaching',
#  'profession',
#  'lead',
#  'me',
#  'to',
#  'believe',
#  'that',
#  'bromwell',
#  'high',
#  's',
#  'satire',
#  'is',
#  'much',
#  'closer',
#  'to',
#  'reality',
#  'than',
#  'is',
#  'teachers',
#  'the',
#  'scramble',
#  'to',
#  'survive',
#  'financially',
#  'the',
#  'insightful',
#  'students',
#  'who',
#  'can',
#  'see',
#  'right',
#  'through',
#  'their',
#  'pathetic',
#  'teachers',
#  'pomp',
#  'the',
#  'pettiness',
#  'of',
#  'the',
#  'whole',
#  'situation',
#  'all',
#  'remind',
#  'me',
#  'of',
#  'the',
#  'schools',
#  'i',
#  'knew',
#  'and',
#  'their',
#  'students',
#  'when',
#  'i',
#  'saw',
#  'the',
#  'episode',
#  'in',
#  'which',
#  'a',
#  'student',
#  'repeatedly',
#  'tried',
#  'to',
#  'burn',
#  'down',
#  'the',
#  'school',
#  'i',
#  'immediately',
#  'recalled',
#  'at',
#  'high',
#  'a',
#  'classic',
#  'line',
#  'inspector',
#  'i',
#  'm',
#  'here',
#  'to',
#  'sack',
#  'one',
#  'of',
#  'your',
#  'teachers',
#  'student',
#  'welcome',
#  'to',
#  'bromwell',
#  'high',
#  'i',
#  'expect',
#  'that',
#  'many',
#  'adults',
#  'of',
#  'my',
#  'age',
#  'think',
#  'that',
#  'bromwell',
#  'high',
#  'is',
#  'far',
#  'fetched',
#  'what',
#  'a',
#  'pity',
#  'that',
#  'it',
#  'isn',
#  't']

# %%
reviews_tokenize = list(map(lambda x: tokenizer.tokenize(x.lower()), reviews))

# %%
len(reviews_tokenize)
# Out:
# 25000

# %%
reviews_tokenize[0]
# Out:
# ['bromwell',
#  'high',
#  'is',
#  'a',
#  'cartoon',
#  'comedy',
#  'it',
#  'ran',
#  'at',
#  'the',
#  'same',
#  'time',
#  'as',
#  'some',
#  'other',
#  'programs',
#  'about',
#  'school',
#  'life',
#  'such',
#  'as',
#  'teachers',
#  'my',
#  'years',
#  'in',
#  'the',
#  'teaching',
#  'profession',
#  'lead',
#  'me',
#  'to',
#  'believe',
#  'that',
#  'bromwell',
#  'high',
#  's',
#  'satire',
#  'is',
#  'much',
#  'closer',
#  'to',
#  'reality',
#  'than',
#  'is',
#  'teachers',
#  'the',
#  'scramble',
#  'to',
#  'survive',
#  'financially',
#  'the',
#  'insightful',
#  'students',
#  'who',
#  'can',
#  'see',
#  'right',
#  'through',
#  'their',
#  'pathetic',
#  'teachers',
#  'pomp',
#  'the',
#  'pettiness',
#  'of',
#  'the',
#  'whole',
#  'situation',
#  'all',
#  'remind',
#  'me',
#  'of',
#  'the',
#  'schools',
#  'i',
#  'knew',
#  'and',
#  'their',
#  'students',
#  'when',
#  'i',
#  'saw',
#  'the',
#  'episode',
#  'in',
#  'which',
#  'a',
#  'student',
#  'repeatedly',
#  'tried',
#  'to',
#  'burn',
#  'down',
#  'the',
#  'school',
#  'i',
#  'immediately',
#  'recalled',
#  'at',
#  'high',
#  'a',
#  'classic',
#  'line',
#  'inspector',
#  'i',
#  'm',
#  'here',
#  'to',
#  'sack',
#  'one',
#  'of',
#  'your',
#  'teachers',
#  'student',
#  'welcome',
#  'to',
#  'bromwell',
#  'high',
#  'i',
#  'expect',
#  'that',
#  'many',
#  'adults',
#  'of',
#  'my',
#  'age',
#  'think',
#  'that',
#  'bromwell',
#  'high',
#  'is',
#  'far',
#  'fetched',
#  'what',
#  'a',
#  'pity',
#  'that',
#  'it',
#  'isn',
#  't']

# %% [markdown]
# ## Stop words
#
#
# 영화리뷰에서 예컨대 this, is, are, an 등등은 문법 구조를 담당할 뿐, 영화리뷰에 관한 정보를 제공하지는 않는다.
#
# 전처리를 통해 performance를 더 낫게 만들 수 있다고 함
#
# nltk의 stopwords와 spacy의 stopwords를 각각 불러오면

# %%
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
print(stop_words)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
from spacy.lang.en.stop_words import STOP_WORDS
print(STOP_WORDS)
# Out:
# {'top', 'afterwards', 'somehow', 'he', 'except', 'while', 'those', 'less', 'whereby', 'whom', 'no', 'yet', 'perhaps', 'everything', 'ten', 'go', 'other', 'bottom', 'five', 'nothing', 'neither', 'besides', 'thereupon', 'off', 'anywhere', 'thence', 'up', 'into', 'along', 'see', 'what', 'regarding', 'would', 'hence', 'whence', 'beforehand', 'mine', 'however', 'some', 'least', 'about', 'many', 'since', 'as', 'here', 'do', 'whose', 'call', 'enough', 'was', 'when', 'due', 'until', 'now', 'towards', 'hereby', 'made', 'and', 'move', 'in', 'hers', 'whereupon', 'eight', 'over', 'too', 'whole', 'twelve', 'whenever', 'if', 'among', 'toward', 'eleven', 'herein', 'not', 'any', 'yours', 'cannot', 'something', 'its', 'just', 'should', 'were', 'rather', 'out', 'nobody', 'ourselves', 'to', 'yourselves', 'so', 'ever', 'hereafter', 'am', 'further', 'even', 'through', 'why', 'also', 'below', 'who', 'never', 'whither', 'former', 'almost', 'after', 'they', 'therein', 'doing', 'seems', 'empty', 'latterly', 'above', 'none', 'others', 'someone', 'therefore', 'by', 'which', 'seeming', 'throughout', 'where', 'whoever', 'him', 'nor', 'us', 'there', 'with', 'already', 'might', 'beside', 'anyone', 'put', 'though', 'but', 'formerly', 'get', 'moreover', 'wherever', 'on', 'otherwise', 'beyond', 'sometimes', "'ve", 'between', 'same', 'anything', 'became', 'you', 'whatever', 'always', 'back', 'used', 'ca', 'against', 'she', 'her', 'name', 'most', 'every', 'seemed', 'we', 'unless', 'i', 'down', 'hereupon', 'before', 'mostly', 'indeed', 'can', 'latter', 'somewhere', 'several', 'or', 'across', 'fifty', 'well', 'myself', 'all', 'of', 'for', 'first', "'re", 'else', 'such', 'wherein', 'three', 'themselves', 'have', 'twenty', 'from', 'under', 'amongst', 'although', 'quite', 'around', 'forty', 'noone', 'must', 'everywhere', 'namely', 'at', 'are', 'keep', 'part', 'sometime', 'me', 're', 'often', 'could', 'this', 'show', 'my', 'nowhere', 'anyhow', 'meanwhile', 'thru', 'another', 'only', 'their', 'much', 'being', 'his', 'few', 'than', 'during', 'two', 'a', 'side', 'yourself', 'has', 'been', 'himself', 'serious', 'that', 'either', 'these', 'give', "'d", 'please', 'say', 'last', 'sixty', 'still', 'did', 'using', 'hundred', 'upon', 'whether', 'herself', "'s", 'may', 'it', 'because', 'does', 'becomes', 'the', 'onto', 'done', 'an', 'itself', 'behind', 'per', 'ours', 'full', 'next', 'alone', 'third', 'front', 'really', 'once', 'make', 'everyone', 'nine', 'is', 'whereafter', "'m", 'each', "n't", 'our', 'thereafter', 'take', 'how', 'be', 'whereas', "'ll", 'four', 'own', 'six', 'your', 'very', 'more', 'various', 'fifteen', 'one', 'will', 'had', 'seem', 'then', 'together', 'thereby', 'within', 'anyway', 'both', 'amount', 'via', 'again', 'them', 'elsewhere', 'thus', 'become', 'becoming', 'nevertheless', 'without'}

# %%
# 중복여부를 확인하는 건 set이 빠르고, iteration 관련해서는 list가 빠르다고 하니
stopwords = set(stop_words).union(STOP_WORDS)
# stopwords를 합친다

# %%
review_test = "this is a good movie".split(" ")
[token for token in review_test if token not in stopwords]
# Out:
# ['good', 'movie']

# %%
review_test = "this is not a good movie".split(" ")
[token for token in review_test if token not in stopwords]
# Out:
# ['good', 'movie']

# %%
# nltk의 stopword 조합에 not과 관련된 데이터가 있다. 이것 때문에 부정표현이 사라지는 현상 발생.
# 따라서 예외처리가 필요하다.
exceptionStopWords = {
    'again',
    'against',
    'ain',
    'almost',
    'among',
    'amongst',
    'amount',
    'anyhow',
    'anyway',
    'aren',
    "aren't",
    'below',
    'bottom',
    'but',
    'cannot',
    'couldn',
    "couldn't",
    'didn',
    "didn't",
    'doesn',
    "doesn't",
    'don',
    "don't",
    'done',
    'down',
    'except',
    'few',
    'hadn',
    "hadn't",
    'hasn',
    "hasn't",
    'haven',
    "haven't",
    'however',
    'isn',
    "isn't",
    'least',
    'mightn',
    "mightn't",
    'must',
    'mustn',
    "mustn't",
    'needn',
    "needn't",
    'neither',
    'never',
    'nevertheless',
    'no',
    'nobody',
    'none',
    'noone',
    'nor',
    'not',
    'nothing',
    'should',
    "should've",
    'shouldn',
    "shouldn't",
    'too',
    'top',
    'up',
    'wasn',
    "wasn't",
    'well',
    'weren',
    "weren't",
    'won',
    "won't",
    'wouldn',
    "wouldn't",
}
# 차집합 개념을 써서 예외 단어를 제거한다
finalstop = stopwords-exceptionStopWords

# %%
# 재사용성을 높이기 위해 함수를 하나 만들자.
def remove_stopwords(review):
    return [token for token in review if token not in finalstop]

# %%
# 전처리하자
reviews = list(map(lambda x: remove_stopwords(x), reviews_tokenize))
reviews[0]
# Out:
# ['bromwell',
#  'high',
#  'cartoon',
#  'comedy',
#  'ran',
#  'time',
#  'programs',
#  'school',
#  'life',
#  'teachers',
#  'years',
#  'teaching',
#  'profession',
#  'lead',
#  'believe',
#  'bromwell',
#  'high',
#  'satire',
#  'closer',
#  'reality',
#  'teachers',
#  'scramble',
#  'survive',
#  'financially',
#  'insightful',
#  'students',
#  'right',
#  'pathetic',
#  'teachers',
#  'pomp',
#  'pettiness',
#  'situation',
#  'remind',
#  'schools',
#  'knew',
#  'students',
#  'saw',
#  'episode',
#  'student',
#  'repeatedly',
#  'tried',
#  'burn',
#  'down',
#  'school',
#  'immediately',
#  'recalled',
#  'high',
#  'classic',
#  'line',
#  'inspector',
#  'sack',
#  'teachers',
#  'student',
#  'welcome',
#  'bromwell',
#  'high',
#  'expect',
#  'adults',
#  'age',
#  'think',
#  'bromwell',
#  'high',
#  'far',
#  'fetched',
#  'pity',
#  'isn']

# %% [markdown]
# ## Lemmetization
#
# 언어학의 한 process.
# - grouping inflected forms of a word into single item.
# - identified by the word's lemma, or dictionary form.
#
# 예컨대 is, are, be 는 전부 Be로 변경하고, walk, walking, walked는 walk로, 말하자면 기본형으로 요약하는 것.
#
# reduce the feature space, improve the performance while more or less preserving the meaning of the review.
#
# spacy에서 이 기능을 제공하며, 영어의 경우 꽤 잘 부합한다고 함
#
# 앞에서 이미 단어 토큰화를 완료했으니, 이 단어들의 일반형만 만들면 된다.

# %%
import spacy
nlp = spacy.load('en')

# %%
doc = nlp('walked')
for token in doc:
    print(token.lemma_)
doc = nlp("isn't")
for token in doc:
    print(token.lemma_)
# Out:
# walk
# be
# not

# %%
def lemmatization(review):
    lemma_result=[]
    
    for words in review:
        doc = nlp(words)
        for token in doc:
            lemma_result.append(token.lemma_)
    return lemma_result

# %%
lemmatization("this isn't good".split())
# Out:
# ['this', 'be', 'not', 'good']

# %%
# 근데 이 함수를 만약 모든 리뷰에 실행할 경우 시간이 상당히 오래 걸린다.
# nlp 함수를 실행할 때 기본적으로 세 가지가 실행된다고 함. parser, tagger, ner
# 이 기능들은 speech tagging, named entity recognition에서 유용하다고 함. 하지만 지금은 필요없음
# 근데 줄여도 오래 걸리는데?
nlp = spacy.load('en', disable=['parser','tagger','ner'])

# %%
reviews = list(map(lambda x: lemmatization(x), reviews))

# %%
reviews
# Out:
# [['bromwell',
#   'high',
#   'cartoon',
#   'comedy',
#   'ran',
#   'time',
#   'programs',
#   'school',
#   'life',
#   'teachers',
#   'years',
#   'teaching',
#   'profession',
#   'lead',
#   'believe',
#   'bromwell',
#   'high',
#   'satire',
#   'closer',
#   'reality',
#   'teachers',
#   'scramble',
#   'survive',
#   'financially',
#   'insightful',
#   'students',
#   'right',
#   'pathetic',
#   'teachers',
#   'pomp',
#   'pettiness',
#   'situation',
#   'remind',
#   'schools',
#   'knew',
#   'students',
#   'saw',
#   'episode',
#   'student',
#   'repeatedly',
#   'tried',
#   'burn',
#   'down',
#   'school',
#   'immediately',
#   'recalled',
#   'high',
#   'classic',
#   'line',
#   'inspector',
#   'sack',
#   'teachers',
#   'student',
#   'welcome',
#   'bromwell',
#   'high',
#   'expect',
#   'adults',
#   'age',
#   'think',
#   'bromwell',
#   'high',
#   'far',
#   'fetched',
#   'pity',
#   'isn'],
#  ['story',
#   'man',
#   'unnatural',
#   'feelings',
#   'pig',
#   'starts',
#   'opening',
#   'scene',
#   'terrific',
#   'example',
#   'absurd',
#   'comedy',
#   'formal',
#   'orchestra',
#   'audience',
#   'turned',
#   'insane',
#   'violent',
#   'mob',
#   'crazy',
#   'chantings',
#   'singers',
#   'unfortunately',
#   'stays',
#   'absurd',
#   'time',
#   'no',
#   'general',
#   'narrative',
#   'eventually',
#   'making',
#   'too',
#   'putting',
#   'era',
#   'should',
#   'turned',
#   'cryptic',
#   'dialogue',
#   'shakespeare',
#   'easy',
#   'grader',
#   'technical',
#   'level',
#   'better',
#   'think',
#   'good',
#   'cinematography',
#   'future',
#   'great',
#   'vilmos',
#   'zsigmond',
#   'future',
#   'stars',
#   'sally',
#   'kirkland',
#   'frederic',
#   'forrest',
#   'seen',
#   'briefly'],
#  ['homelessness',
#   'houselessness',
#   'george',
#   'carlin',
#   'stated',
#   'issue',
#   'years',
#   'but',
#   'never',
#   'plan',
#   'help',
#   'street',
#   'considered',
#   'human',
#   'going',
#   'school',
#   'work',
#   'vote',
#   'matter',
#   'people',
#   'think',
#   'homeless',
#   'lost',
#   'cause',
#   'worrying',
#   'things',
#   'racism',
#   'war',
#   'iraq',
#   'pressuring',
#   'kids',
#   'succeed',
#   'technology',
#   'elections',
#   'inflation',
#   'worrying',
#   'end',
#   'up',
#   'streets',
#   'br',
#   'br',
#   'but',
#   'given',
#   'bet',
#   'live',
#   'streets',
#   'month',
#   'luxuries',
#   'home',
#   'entertainment',
#   'sets',
#   'bathroom',
#   'pictures',
#   'wall',
#   'computer',
#   'treasure',
#   'like',
#   'homeless',
#   'goddard',
#   'bolt',
#   'lesson',
#   'br',
#   'br',
#   'mel',
#   'brooks',
#   'directs',
#   'stars',
#   'bolt',
#   'plays',
#   'rich',
#   'man',
#   'world',
#   'deciding',
#   'bet',
#   'sissy',
#   'rival',
#   'jeffery',
#   'tambor',
#   'live',
#   'streets',
#   'thirty',
#   'days',
#   'luxuries',
#   'bolt',
#   'succeeds',
#   'wants',
#   'future',
#   'project',
#   'making',
#   'buildings',
#   'bet',
#   'bolt',
#   'thrown',
#   'street',
#   'bracelet',
#   'leg',
#   'monitor',
#   'step',
#   'sidewalk',
#   'given',
#   'nickname',
#   'pepto',
#   'vagrant',
#   'written',
#   'forehead',
#   'bolt',
#   'meets',
#   'characters',
#   'including',
#   'woman',
#   'molly',
#   'lesley',
#   'ann',
#   'warren',
#   'ex',
#   'dancer',
#   'got',
#   'divorce',
#   'losing',
#   'home',
#   'pals',
#   'sailor',
#   'howard',
#   'morris',
#   'fumes',
#   'teddy',
#   'wilson',
#   'streets',
#   'survivors',
#   'bolt',
#   'isn',
#   'not',
#   'reaching',
#   'mutual',
#   'agreements',
#   'like',
#   'rich',
#   'fight',
#   'flight',
#   'kill',
#   'killed',
#   'br',
#   'br',
#   'love',
#   'connection',
#   'molly',
#   'bolt',
#   'wasn',
#   'necessary',
#   'plot',
#   'found',
#   'life',
#   'stinks',
#   'mel',
#   'brooks',
#   'observant',
#   'films',
#   'prior',
#   'comedy',
#   'shows',
#   'tender',
#   'compared',
#   'slapstick',
#   'work',
#   'blazing',
#   'saddles',
#   'young',
#   'frankenstein',
#   'spaceballs',
#   'matter',
#   'like',
#   'valuable',
#   'losing',
#   'day',
#   'hand',
#   'making',
#   'stupid',
#   'bet',
#   'like',
#   'rich',
#   'people',
#   'don',
#   'know',
#   'money',
#   'maybe',
#   'should',
#   'homeless',
#   'instead',
#   'like',
#   'monopoly',
#   'money',
#   'br',
#   'br',
#   'maybe',
#   'film',
#   'inspire',
#   'help'],
#  ['airport',
#   'starts',
#   'brand',
#   'new',
#   'luxury',
#   'plane',
#   'loaded',
#   'up',
#   'valuable',
#   'paintings',
#   'belonging',
#   'rich',
#   'businessman',
#   'philip',
#   'stevens',
#   'james',
#   'stewart',
#   'flying',
#   'bunch',
#   'vip',
#   'estate',
#   'preparation',
#   'opened',
#   'public',
#   'museum',
#   'board',
#   'stevens',
#   'daughter',
#   'julie',
#   'kathleen',
#   'quinlan',
#   'son',
#   'luxury',
#   'jetliner',
#   'takes',
#   'planned',
#   'but',
#   'mid',
#   'air',
#   'plane',
#   'hi',
#   'jacked',
#   'co',
#   'pilot',
#   'chambers',
#   'robert',
#   'foxworth',
#   'accomplice',
#   'banker',
#   'monte',
#   'markham',
#   'wilson',
#   'michael',
#   'pataki',
#   'knock',
#   'passengers',
#   'crew',
#   'sleeping',
#   'gas',
#   'plan',
#   'steal',
#   'valuable',
#   'cargo',
#   'land',
#   'disused',
#   'plane',
#   'strip',
#   'isolated',
#   'island',
#   'but',
#   'making',
#   'descent',
#   'chambers',
#   'almost',
#   'hits',
#   'oil',
#   'rig',
#   'ocean',
#   'loses',
#   'control',
#   'plane',
#   'sending',
#   'crashing',
#   'sea',
#   'sinks',
#   'bottom',
#   'right',
#   'bang',
#   'middle',
#   'bermuda',
#   'triangle',
#   'air',
#   'short',
#   'supply',
#   'water',
#   'leaking',
#   'flown',
#   'miles',
#   'course',
#   'problems',
#   'mount',
#   'survivor',
#   'await',
#   'help',
#   'time',
#   'fast',
#   'running',
#   'br',
#   'br',
#   'known',
#   'slightly',
#   'different',
#   'tile',
#   'airport',
#   'second',
#   'sequel',
#   'smash',
#   'hit',
#   'disaster',
#   'thriller',
#   'airport',
#   'directed',
#   'jerry',
#   'jameson',
#   'again',
#   'like',
#   'predecessors',
#   'airport',
#   'sort',
#   'forgotten',
#   'classic',
#   'entertaining',
#   'not',
#   'necessarily',
#   'right',
#   'reasons',
#   'airport',
#   'films',
#   'seen',
#   'far',
#   'actually',
#   'liked',
#   'best',
#   'favourite',
#   'plot',
#   'nice',
#   'mid',
#   'air',
#   'hi',
#   'jacking',
#   'crashing',
#   'didn',
#   'oil',
#   'rig',
#   'sinking',
#   'maybe',
#   'makers',
#   'trying',
#   'cross',
#   'original',
#   'airport',
#   'popular',
#   'disaster',
#   'flick',
#   'period',
#   'poseidon',
#   'adventure',
#   'submerged',
#   'stays',
#   'end',
#   'stark',
#   'dilemma',
#   'facing',
#   'trapped',
#   'inside',
#   'suffocate',
#   'air',
#   'runs',
#   'drown',
#   'floods',
#   'doors',
#   'opened',
#   'decent',
#   'idea',
#   'great',
#   'little',
#   'disaster',
#   'flick',
#   'but',
#   'bad',
#   'unsympathetic',
#   'character',
#   'dull',
#   'dialogue',
#   'lethargic',
#   'set',
#   'pieces',
#   'real',
#   'lack',
#   'danger',
#   'suspense',
#   'tension',
#   'means',
#   'missed',
#   'opportunity',
#   'sluggish',
#   'plot',
#   'keeps',
#   'entertained',
#   'odd',
#   'minutes',
#   'not',
#   'happens',
#   'plane',
#   'sinks',
#   'not',
#   'urgency',
#   'thought',
#   'should',
#   'navy',
#   'involved',
#   'things',
#   'don',
#   'pick',
#   'up',
#   'few',
#   'shots',
#   'huge',
#   'ships',
#   'helicopters',
#   'flying',
#   'but',
#   'lacking',
#   'george',
#   'kennedy',
#   'jinxed',
#   'airline',
#   'worker',
#   'joe',
#   'patroni',
#   'but',
#   'gets',
#   'couple',
#   'scenes',
#   'barely',
#   'says',
#   'preferring',
#   'look',
#   'worried',
#   'background',
#   'br',
#   'br',
#   'home',
#   'video',
#   'theatrical',
#   'version',
#   'airport',
#   'run',
#   'minutes',
#   'tv',
#   'versions',
#   'add',
#   'extra',
#   'hour',
#   'footage',
#   'including',
#   'new',
#   'opening',
#   'credits',
#   'sequence',
#   'scenes',
#   'george',
#   'kennedy',
#   'patroni',
#   'flashbacks',
#   'flesh',
#   'character',
#   'longer',
#   'rescue',
#   'scenes',
#   'discovery',
#   'couple',
#   'dead',
#   'bodies',
#   'including',
#   'navigator',
#   'like',
#   'extra',
#   'footage',
#   'not',
#   'sure',
#   'sit',
#   'near',
#   'hour',
#   'cut',
#   'airport',
#   'expected',
#   'film',
#   'dated',
#   'badly',
#   'horrible',
#   'fashions',
#   'interior',
#   'design',
#   'choices',
#   'no',
#   'toy',
#   'plane',
#   'model',
#   'effects',
#   'aren',
#   'great',
#   'airport',
#   'sequels',
#   'takes',
#   'pride',
#   'place',
#   'razzie',
#   'award',
#   'hall',
#   'shame',
#   'think',
#   'lots',
#   'worse',
#   'films',
#   'reckon',
#   'little',
#   'harsh',
#   'action',
#   'scenes',
#   'little',
#   'dull',
#   'unfortunately',
#   'pace',
#   'slow',
#   'not',
#   'excitement',
#   'tension',
#   'generated',
#   'shame',
#   'reckon',
#   'pretty',
#   'good',
#   'film',
#   'properly',
#   'br',
#   'br',
#   'production',
#   'values',
#   'alright',
#   'nothing',
#   'spectacular',
#   'acting',
#   'isn',
#   'great',
#   'time',
#   'oscar',
#   'winner',
#   'jack',
#   'lemmon',
#   'said',
#   'mistake',
#   'star',
#   'time',
#   'oscar',
#   'winner',
#   'james',
#   'stewart',
#   'looks',
#   'old',
#   'frail',
#   'time',
#   'oscar',
#   'winner',
#   'lee',
#   'grant',
#   'looks',
#   'drunk',
#   'sir',
#   'christopher',
#   'lee',
#   'given',
#   'little',
#   'plenty',
#   'familiar',
#   'faces',
#   'look',
#   'too',
#   'br',
#   'br',
#   'airport',
#   'disaster',
#   'orientated',
#   'airport',
#   'films',
#   'far',
#   'liked',
#   'ideas',
#   'bit',
#   'silly',
#   'production',
#   'bland',
#   'direction',
#   'doesn',
#   'help',
#   'film',
#   'sunken',
#   'plane',
#   'shouldn',
#   'boring',
#   'lethargic',
#   'followed',
#   'concorde',
#   'airport'],
#  ['brilliant',
#   'acting',
#   'lesley',
#   'ann',
#   'warren',
#   'best',
#   'dramatic',
#   'hobo',
#   'lady',
#   'seen',
#   'love',
#   'scenes',
#   'clothes',
#   'warehouse',
#   'second',
#   'none',
#   'corn',
#   'face',
#   'classic',
#   'good',
#   'blazing',
#   'saddles',
#   'lawyers',
#   'superb',
#   'accused',
#   'turncoat',
#   'selling',
#   'boss',
#   'dishonest',
#   'lawyer',
#   'pepto',
#   'bolt',
#   'shrugs',
#   'indifferently',
#   'lawyer',
#   'says',
#   'funny',
#   'words',
#   'jeffrey',
#   'tambor',
#   'favorite',
#   'later',
#   'larry',
#   'sanders',
#   'fantastic',
#   'too',
#   'mad',
#   'millionaire',
#   'wants',
#   'crush',
#   'ghetto',
#   'character',
#   'malevolent',
#   'usual',
#   'hospital',
#   'scene',
#   'scene',
#   'homeless',
#   'invade',
#   'demolition',
#   'site',
#   'time',
#   'classics',
#   'look',
#   'legs',
#   'scene',
#   'big',
#   'diggers',
#   'fighting',
#   'bleeds',
#   'movie',
#   'gets',
#   'better',
#   'time'],
#  ['film',
#   'lacked',
#   'couldn',
#   'finger',
#   'charisma',
#   'leading',
#   'actress',
#   'inevitably',
#   'translated',
#   'lack',
#   'chemistry',
#   'shared',
#   'screen',
#   'leading',
#   'man',
#   'romantic',
#   'scenes',
#   'came',
#   'merely',
#   'actors',
#   'play',
#   'well',
#   'director',
#   'miscalculated',
#   'needed',
#   'actors',
#   'don',
#   'know',
#   'br',
#   'br',
#   'but',
#   'screenplay',
#   'exactly',
#   'chef',
#   'love',
#   'enamored',
#   'culinary',
#   'skills',
#   'restaurant',
#   'ultimately',
#   'youthful',
#   'exploits',
#   'anybody',
#   'never',
#   'convinced',
#   'love',
#   'princess',
#   'br',
#   'br',
#   'disappointed',
#   'movie',
#   'but',
#   'don',
#   'forget',
#   'nominated',
#   'oscar',
#   'judge'],
#  ['easily',
#   'underrated',
#   'film',
#   'inn',
#   'brooks',
#   'cannon',
#   'sure',
#   'flawed',
#   'not',
#   'realistic',
#   'view',
#   'homelessness',
#   'unlike',
#   'citizen',
#   'kane',
#   'gave',
#   'realistic',
#   'view',
#   'lounge',
#   'singers',
#   'titanic',
#   'gave',
#   'realistic',
#   'view',
#   'italians',
#   'idiots',
#   'jokes',
#   'fall',
#   'flat',
#   'but',
#   'film',
#   'lovable',
#   'way',
#   'comedies',
#   'not',
#   'pull',
#   'story',
#   'traditionally',
#   'reviled',
#   'members',
#   'society',
#   'truly',
#   'impressive',
#   'not',
#   'fisher',
#   'king',
#   'but',
#   'not',
#   'crap',
#   'complaint',
#   'brooks',
#   'should',
#   'cast',
#   'lead',
#   'love',
#   'mel',
#   'director',
#   'writer',
#   'not',
#   'lead'],
#  ['sorry',
#   'know',
#   'supposed',
#   'art',
#   'film',
#   'but',
#   'wow',
#   'should',
#   'handed',
#   'guns',
#   'screening',
#   'people',
#   'blow',
#   'brains',
#   'not',
#   'watch',
#   'scene',
#   'design',
#   'photographic',
#   'direction',
#   'excellent',
#   'story',
#   'too',
#   'painful',
#   'watch',
#   'absence',
#   'sound',
#   'track',
#   'brutal',
#   'loooonnnnng',
#   'shots',
#   'too',
#   'long',
#   'long',
#   'watch',
#   'people',
#   'sitting',
#   'talking',
#   'especially',
#   'dialogue',
#   'people',
#   'complaining',
#   'hard',
#   'time',
#   'getting',
#   'film',
#   'performances',
#   'excellent',
#   'but',
#   'dark',
#   'sombre',
#   'uninspired',
#   'stuff',
#   'thing',
#   'liked',
#   'maureen',
#   'stapleton',
#   'red',
#   'dress',
#   'dancing',
#   'scene',
#   'ripoff',
#   'bergman',
#   'no',
#   'fan',
#   'f',
#   'think',
#   'says',
#   'enjoyed',
#   'hours',
#   'well',
#   'lying'],
#  ['not',
#   'typical',
#   'mel',
#   'brooks',
#   'film',
#   'slapstick',
#   'movies',
#   'actually',
#   'plot',
#   'followable',
#   'leslie',
#   'ann',
#   'warren',
#   'movie',
#   'fantastic',
#   'rated',
#   'actress',
#   'moments',
#   'fleshed',
#   'bit',
#   'scenes',
#   'probably',
#   'cut',
#   'room',
#   'but',
#   'worth',
#   'price',
#   'rent',
#   'acting',
#   'good',
#   'overall',
#   'brooks',
#   'good',
#   'job',
#   'characteristic',
#   'speaking',
#   'directly',
#   'audience',
#   'again',
#   'warren',
#   'best',
#   'actor',
#   'movie',
#   'but',
#   'fume',
#   'sailor',
#   'played',
#   'parts',
#   'well'],
#  ['little',
#   'parents',
#   'took',
#   'theater',
#   'interiors',
#   'movies',
#   'watched',
#   'parents',
#   'but',
#   'walked',
#   'never',
#   'seen',
#   'interiors',
#   'recently',
#   'lived',
#   'rest',
#   'life',
#   'pretentious',
#   'ponderous',
#   'painfully',
#   'boring',
#   'piece',
#   'wine',
#   'cheese',
#   'tripe',
#   'woody',
#   'allen',
#   'favorite',
#   'directors',
#   'but',
#   'interiors',
#   'far',
#   'worst',
#   'piece',
#   'crap',
#   'career',
#   'unmistakable',
#   'style',
#   'ingmar',
#   'berman',
#   'allen',
#   'gives',
#   'dark',
#   'angular',
#   'muted',
#   'insight',
#   'lives',
#   'family',
#   'wrought',
#   'psychological',
#   'damage',
#   'caused',
#   'divorce',
#   'estrangement',
#   'career',
#   'love',
#   'non',
#   'love',
#   'halitosis',
#   'film',
#   'intentionally',
#   'no',
#   'comic',
#   'relief',
#   'no',
#   'music',
#   'drenched',
#   'shadowy',
#   'pathos',
#   'film',
#   'style',
#   'best',
#   'defined',
#   'expressionist',
#   'nature',
#   'improvisational',
#   'method',
#   'dialogue',
#   'illicit',
#   'pronounced',
#   'depth',
#   'meaning',
#   'truth',
#   'but',
#   'woody',
#   'allen',
#   'no',
#   'ingmar',
#   'bergman',
#   'film',
#   'painfully',
#   'slow',
#   'dull',
#   'but',
#   'simply',
#   'no',
#   'connection',
#   'sympathy',
#   'characters',
#   'instead',
#   'felt',
#   'contempt',
#   'parade',
#   'shuffling',
#   'whining',
#   'nicotine',
#   'stained',
#   'martyrs',
#   'perpetual',
#   'quest',
#   'identity',
#   'amid',
#   'backdrop',
#   'cosmopolitan',
#   'affluence',
#   'baked',
#   'brie',
#   'intelligentsia',
#   'story',
#   'looms',
#   'like',
#   'fart',
#   'room',
#   'speaks',
#   'affected',
#   'platitudes',
#   'elevated',
#   'language',
#   'cigarettes',
#   'lost',
#   'struggling',
#   'desperate',
#   'find',
#   'direction',
#   'understanding',
#   'goes',
#   'point',
#   'want',
#   'slap',
#   'never',
#   'resolution',
#   'interminable',
#   'introspective',
#   'babble',
#   'nothing',
#   'psychological',
#   'drama',
#   'taken',
#   'extreme',
#   'audience',
#   'ability',
#   'connect',
#   'woody',
#   'allen',
#   'chose',
#   'characters',
#   'immersed',
#   'feel',
#   'left',
#   'reason',
#   'found',
#   'movie',
#   'painfully',
#   'self',
#   'indulgent',
#   'spiritually',
#   'draining',
#   'going',
#   'but',
#   'insistence',
#   'promoting',
#   'message',
#   'prozac',
#   'prose',
#   'distorted',
#   'film',
#   'techniques',
#   'jettisons',
#   'past',
#   'point',
#   'relevance',
#   'highly',
#   'recommend',
#   'feeling',
#   'little',
#   'too',
#   'happy',
#   'need',
#   'remind',
#   'death',
#   'let',
#   'pretend',
#   'film',
#   'never',
#   'happened'],
#  ['isn',
#   'comedic',
#   'robin',
#   'williams',
#   'nor',
#   'quirky',
#   'insane',
#   'robin',
#   'williams',
#   'recent',
#   'thriller',
#   'fame',
#   'hybrid',
#   'classic',
#   'drama',
#   'dramatization',
#   'mixed',
#   'robin',
#   'new',
#   'love',
#   'thriller',
#   'but',
#   'isn',
#   'thriller',
#   'se',
#   'mystery',
#   'suspense',
#   'vehicle',
#   'williams',
#   'attempts',
#   'locate',
#   'sick',
#   'boy',
#   'keeper',
#   'br',
#   'br',
#   'starring',
#   'sandra',
#   'oh',
#   'rory',
#   'culkin',
#   'suspense',
#   'drama',
#   'plays',
#   'pretty',
#   'like',
#   'news',
#   'report',
#   'william',
#   'character',
#   'gets',
#   'close',
#   'achieving',
#   'goal',
#   'br',
#   'br',
#   'must',
#   'highly',
#   'entertained',
#   'movie',
#   'fails',
#   'teach',
#   'guide',
#   'inspect',
#   'amuse',
#   'felt',
#   'like',
#   'watching',
#   'guy',
#   'williams',
#   'actually',
#   'performing',
#   'actions',
#   'person',
#   'perspective',
#   'words',
#   'felt',
#   'real',
#   'able',
#   'subscribe',
#   'premise',
#   'story',
#   'br',
#   'br',
#   'worth',
#   'watch',
#   'definitely',
#   'not',
#   'friday',
#   'saturday',
#   'night',
#   'fare',
#   'br',
#   'br',
#   'rates',
#   'br',
#   'br',
#   'fiend'],
#  ['appears',
#   'critics',
#   'find',
#   'idea',
#   'woody',
#   'allen',
#   'drama',
#   'unpalatable',
#   'good',
#   'reason',
#   'unbearably',
#   'wooden',
#   'pretentious',
#   'imitations',
#   'bergman',
#   'let',
#   'not',
#   'kid',
#   'critics',
#   'supportive',
#   'allen',
#   'bergman',
#   'pretensions',
#   'allen',
#   'whining',
#   'accusations',
#   'contrary',
#   'notwithstanding',
#   'don',
#   'allen',
#   'generally',
#   'applauded',
#   'originality',
#   'imitating',
#   'bergman',
#   'but',
#   'contemporaneous',
#   'brian',
#   'depalma',
#   'excoriated',
#   'ripping',
#   'hitchcock',
#   'suspense',
#   'horror',
#   'films',
#   'robin',
#   'wood',
#   'view',
#   'strange',
#   'form',
#   'cultural',
#   'snobbery',
#   'agree'],
#  ['yes',
#   'art',
#   'successfully',
#   'slow',
#   'paced',
#   'thriller',
#   'br',
#   'br',
#   'story',
#   'unfolds',
#   'nice',
#   'volumes',
#   'don',
#   'notice',
#   'happening',
#   'br',
#   'br',
#   'fine',
#   'performance',
#   'robin',
#   'williams',
#   'sexuality',
#   'angles',
#   'film',
#   'unnecessary',
#   'probably',
#   'affect',
#   'enjoy',
#   'film',
#   'however',
#   'core',
#   'plot',
#   'engaging',
#   'movie',
#   'doesn',
#   'rush',
#   'grips',
#   'wondering',
#   'direction',
#   'good',
#   'use',
#   'lights',
#   'achieve',
#   'desired',
#   'affects',
#   'suspense',
#   'unexpectedness',
#   'good',
#   'br',
#   'br',
#   'nice',
#   'time',
#   'watch',
#   'looking',
#   'lay',
#   'hear',
#   'thrilling',
#   'short',
#   'story'],
#  ['second',
#   'attempt',
#   'new',
#   'york',
#   'intellectual',
#   'years',
#   'swedish',
#   'film',
#   'susan',
#   'sontag',
#   'brother',
#   'carl',
#   'sweden',
#   'swedish',
#   'actors',
#   'no',
#   'results',
#   'oscar',
#   'wilde',
#   'said',
#   'best',
#   'reference',
#   'dickens',
#   'old',
#   'curiosity',
#   'shop',
#   'heart',
#   'stone',
#   'not',
#   'laugh',
#   'loud',
#   'death',
#   'little',
#   'nell',
#   'pretty',
#   'thing',
#   'interiors',
#   'chock',
#   'solemnly',
#   'intoned',
#   'howlers',
#   'afraid',
#   'anger',
#   'looking',
#   'middle',
#   'distance',
#   'don',
#   'like',
#   'directorial',
#   'quotations',
#   'use',
#   'polite',
#   'term',
#   'bergman',
#   'close',
#   'parody',
#   'incredibly',
#   'self',
#   'involved',
#   'family',
#   'reminding',
#   'brilliant',
#   'talented',
#   'point',
#   'strangulation',
#   'read',
#   'poem',
#   'day',
#   'don',
#   'know',
#   'new',
#   'yorker',
#   'oh',
#   'old',
#   'poem',
#   'reworked',
#   'far',
#   'not',
#   'caring',
#   'people',
#   'however',
#   'found',
#   'hilarious',
#   'dialog',
#   'exactly',
#   'like',
#   'funny',
#   'stuff',
#   'allen',
#   'earlier',
#   'films',
#   'directed',
#   'actors',
#   'play',
#   'lines',
#   'straight',
#   'not',
#   'cast',
#   'movie',
#   'poor',
#   'mary',
#   'beth',
#   'hurt',
#   'copy',
#   'thespian',
#   'tics',
#   'intonations',
#   'neurotic',
#   'habits',
#   'turning',
#   'embarrassing',
#   'surrogate',
#   'like',
#   'kenneth',
#   'branagh',
#   'celebrity',
#   'br',
#   'br',
#   'basic',
#   'plot',
#   'dysfunctional',
#   'family',
#   'quietly',
#   'domineering',
#   'mother',
#   'lifted',
#   'bergman',
#   'winter',
#   'light',
#   'basic',
#   'family',
#   'melodrama',
#   'tricked',
#   'up',
#   'lot',
#   'existential',
#   'angst',
#   'comes',
#   'shopworn',
#   'visual',
#   'aural',
#   'tricks',
#   'deafening',
#   'scratching',
#   'pencil',
#   'paper',
#   'towering',
#   'surf',
#   'dwarfs',
#   'people',
#   'walking',
#   'beach',
#   'etc',
#   'etc',
#   'br',
#   'br',
#   'allen',
#   'later',
#   'films',
#   'embarrassing',
#   'but',
#   'far',
#   'entertaining',
#   'interiors',
#   'woody',
#   'rarely',
#   'funnier',
#   'movie'],
#  ['critically',
#   'acclaimed',
#   'psychological',
#   'thriller',
#   'based',
#   'true',
#   'events',
#   'gabriel',
#   'robin',
#   'williams',
#   'celebrated',
#   'writer',
#   'late',
#   'night',
#   'talk',
#   'host',
#   'captivated',
#   'harrowing',
#   'story',
#   'young',
#   'listener',
#   'adoptive',
#   'mother',
#   'toni',
#   'collette',
#   'troubling',
#   'questions',
#   'arise',
#   'boy',
#   'story',
#   'however',
#   'gabriel',
#   'finds',
#   'drawn',
#   'widening',
#   'mystery',
#   'hides',
#   'deadly',
#   'secret',
#   'according',
#   'film',
#   'official',
#   'synopsis',
#   'br',
#   'br',
#   'should',
#   'stop',
#   'reading',
#   'comments',
#   'watch',
#   'film',
#   'br',
#   'br',
#   'lose',
#   'leg',
#   'ending',
#   'ms',
#   'collette',
#   'planning',
#   'new',
#   'life',
#   'should',
#   'chopped',
#   'sent',
#   'deleted',
#   'scenes',
#   'land',
#   'overkill',
#   'true',
#   'nature',
#   'physical',
#   'mental',
#   'ailments',
#   'should',
#   'obvious',
#   'time',
#   'mr',
#   'williams',
#   'returns',
#   'new',
#   'york',
#   'possibly',
#   'blindness',
#   'question',
#   'but',
#   'revelation',
#   'certain',
#   'highway',
#   'video',
#   'tape',
#   'scenes',
#   'film',
#   'benefit',
#   'editing',
#   'director',
#   'cut',
#   'br',
#   'br',
#   'williams',
#   'bobby',
#   'cannavale',
#   'jess',
#   'don',
#   'initially',
#   'believable',
#   'couple',
#   'scene',
#   'establishing',
#   'relationship',
#   'helped',
#   'set',
#   'stage',
#   'cast',
#   'exemplary',
#   'williams',
#   'offers',
#   'exceptionally',
#   'strong',
#   'characterization',
#   'not',
#   'gay',
#   'impersonation',
#   'sandra',
#   'oh',
#   'anna',
#   'joe',
#   'morton',
#   'ashe',
#   'rory',
#   'culkin',
#   'pete',
#   'logand',
#   'perfect',
#   'br',
#   'br',
#   'best',
#   'collette',
#   'donna',
#   'belongs',
#   'creepy',
#   'hall',
#   'fame',
#   'ms',
#   'oh',
#   'correct',
#   'saying',
#   'collette',
#   'know',
#   'like',
#   'guy',
#   'psycho',
#   'years',
#   'organizations',
#   'giving',
#   'acting',
#   'awards',
#   'reach',
#   'women',
#   'slighter',
#   'dispersion',
#   'roles',
#   'certainly',
#   'noticed',
#   'collette',
#   'award',
#   'consideration',
#   'good',
#   'director',
#   'patrick',
#   'stettner',
#   'definitely',
#   'evokes',
#   'hitchcock',
#   'makes',
#   'getting',
#   'sandwich',
#   'vending',
#   'machine',
#   'suspenseful',
#   'br',
#   'br',
#   'finally',
#   'writers',
#   'stettner',
#   'armistead',
#   'maupin',
#   'terry',
#   'anderson',
#   'deserve',
#   'gratitude',
#   'flight',
#   'attendants',
#   'br',
#   'br',
#   'night',
#   'listener',
#   'patrick',
#   'stettner',
#   'robin',
#   'williams',
#   'toni',
#   'collette',
#   'sandra',
#   'oh',
#   'rory',
#   'culkin'],
#  ['don',
#   'know',
#   'blame',
#   'timid',
#   'writers',
#   'clueless',
#   'director',
#   'movies',
#   'paid',
#   'stars',
#   'angie',
#   'charlie',
#   'denise',
#   'rosanna',
#   'jon',
#   'wasn',
#   'left',
#   'movie',
#   'entertaining',
#   'but',
#   'veil',
#   'timidity',
#   'cowardice',
#   'hung',
#   'scene',
#   'got',
#   'r',
#   'rating',
#   'anyway',
#   'ubiquitous',
#   'bubble',
#   'bath',
#   'scene',
#   'shot',
#   'year',
#   'old',
#   'woman',
#   'not',
#   'angie',
#   'harmon',
#   'sheen',
#   'sleepwalk',
#   'potentially',
#   'hot',
#   'relationships',
#   'beautiful',
#   'sexy',
#   'actresses',
#   'world',
#   'looking',
#   'laughs',
#   'not',
#   'cast',
#   'whoopi',
#   'goldberg',
#   'judy',
#   'tenuta',
#   'instead',
#   'predictable',
#   'surprised',
#   'find',
#   'director',
#   'wasn',
#   'year',
#   'old',
#   'waste',
#   'not',
#   'viewers',
#   'but',
#   'actors',
#   'well'],
#  ['night',
#   'listener',
#   'robin',
#   'williams',
#   'toni',
#   'collette',
#   'bobby',
#   'cannavale',
#   'rory',
#   'culkin',
#   'joe',
#   'morton',
#   'sandra',
#   'oh',
#   'john',
#   'cullum',
#   'lisa',
#   'emery',
#   'becky',
#   'ann',
#   'baker',
#   'dir',
#   'patrick',
#   'stettner',
#   'br',
#   'br',
#   'hitchcockian',
#   'suspenser',
#   'gives',
#   'williams',
#   'stand',
#   'low',
#   'key',
#   'performance',
#   'br',
#   'br',
#   'celebrities',
#   'fans',
#   'near',
#   'paranoia',
#   'associates',
#   'almost',
#   'norm',
#   'br',
#   'br',
#   'latest',
#   'derange',
#   'fan',
#   'scenario',
#   'based',
#   'true',
#   'events',
#   'no',
#   'williams',
#   'stars',
#   'talk',
#   'radio',
#   'personality',
#   'named',
#   'gabriel',
#   'no',
#   'reads',
#   'stories',
#   'penned',
#   'airwaves',
#   'accumulated',
#   'interesting',
#   'fan',
#   'form',
#   'young',
#   'boy',
#   'named',
#   'pete',
#   'logand',
#   'culkin',
#   'submitted',
#   'manuscript',
#   'travails',
#   'troubled',
#   'youth',
#   'no',
#   'editor',
#   'ashe',
#   'morton',
#   'gives',
#   'no',
#   'read',
#   'br',
#   'br',
#   'no',
#   'naturally',
#   'disturbed',
#   'but',
#   'ultimately',
#   'intrigued',
#   'nightmarish',
#   'existence',
#   'pete',
#   'abducted',
#   'sexually',
#   'abused',
#   'years',
#   'finally',
#   'rescued',
#   'nurse',
#   'named',
#   'donna',
#   'collette',
#   'giving',
#   'excellent',
#   'performance',
#   'adopted',
#   'boy',
#   'but',
#   'correspondence',
#   'no',
#   'reveals',
#   'pete',
#   'dying',
#   'aids',
#   'naturally',
#   'no',
#   'wants',
#   'meet',
#   'fans',
#   'but',
#   'suddenly',
#   'doubt',
#   'possibly',
#   'devious',
#   'ulterior',
#   'motives',
#   'seed',
#   'planted',
#   'estranged',
#   'lover',
#   'jess',
#   'cannavale',
#   'sudden',
#   'departure',
#   'new',
#   'york',
#   'city',
#   'apartment',
#   'no',
#   'emotional',
#   'tailspin',
#   'grown',
#   'tempest',
#   'teacup',
#   'decides',
#   'investigating',
#   'donna',
#   'pete',
#   'backgrounds',
#   'discovering',
#   'truths',
#   'didn',
#   'anticipate',
#   'br',
#   'br',
#   'written',
#   'armistead',
#   'maupin',
#   'co',
#   'wrote',
#   'screenplay',
#   'lover',
#   'terry',
#   'anderson',
#   'film',
#   'novice',
#   'director',
#   'stettner',
#   'based',
#   'true',
#   'story',
#   'fan',
#   'hoax',
#   'found',
#   'hitchcockian',
#   'moments',
#   'run',
#   'tilt',
#   'like',
#   'good',
#   'old',
#   'fashioned',
#   'pot',
#   'boiler',
#   'helps',
#   'williams',
#   'gives',
#   'stand',
#   'low',
#   'key',
#   'performance',
#   'conflicted',
#   'good',
#   'hearted',
#   'personality',
#   'genuinely',
#   'wants',
#   'believe',
#   'number',
#   'fan',
#   'fact',
#   'real',
#   'love',
#   'thing',
#   'escaped',
#   'reality',
#   'unsettling',
#   'dreadful',
#   'moments',
#   'creepy',
#   'collette',
#   'physical',
#   'trait',
#   'leave',
#   'unmentioned',
#   'but',
#   'underlines',
#   'desperation',
#   'character',
#   'rattle',
#   'core',
#   'br',
#   'br',
#   'however',
#   'film',
#   'runs',
#   'gas',
#   'eventually',
#   'bit',
#   'repetitive',
#   'predictable',
#   'despite',
#   'finely',
#   'directed',
#   'piece',
#   'hoodwink',
#   'mystery',
#   'stettner',
#   'pays',
#   'listen',
#   'inner',
#   'voice',
#   'careful',
#   'hope'],
#  ['film',
#   'mediocre',
#   'best',
#   'angie',
#   'harmon',
#   'funny',
#   'bag',
#   'hammers',
#   'bitchy',
#   'demeanor',
#   'law',
#   'order',
#   'carries',
#   'failed',
#   'attempt',
#   'comedy',
#   'charlie',
#   'sheen',
#   'come',
#   'unscathed',
#   'horrible',
#   'anti',
#   'comedy',
#   'positive',
#   'thing',
#   'come',
#   'mess',
#   'charlie',
#   'denise',
#   'marriage',
#   'hopefully',
#   'effort',
#   'produces',
#   'better',
#   'results'],
#  ['know',
#   'robin',
#   'williams',
#   'god',
#   'bless',
#   'constantly',
#   'shooting',
#   'foot',
#   'lately',
#   'dumb',
#   'comedies',
#   'done',
#   'decade',
#   'exception',
#   'death',
#   'smoochy',
#   'bombed',
#   'came',
#   'but',
#   'cult',
#   'classic',
#   'dramas',
#   'lately',
#   'fantastic',
#   'especially',
#   'insomnia',
#   'hour',
#   'photo',
#   'night',
#   'listener',
#   'despite',
#   'mediocre',
#   'reviews',
#   'quick',
#   'dvd',
#   'release',
#   'among',
#   'best',
#   'work',
#   'period',
#   'br',
#   'br',
#   'chilling',
#   'story',
#   'doesn',
#   'include',
#   'serial',
#   'killer',
#   'physically',
#   'dangerous',
#   'matter',
#   'concept',
#   'film',
#   'based',
#   'actual',
#   'case',
#   'fraud',
#   'officially',
#   'confirmed',
#   'high',
#   'school',
#   'read',
#   'autobiography',
#   'child',
#   'named',
#   'anthony',
#   'godby',
#   'johnson',
#   'suffered',
#   'horrific',
#   'abuse',
#   'eventually',
#   'contracted',
#   'aids',
#   'result',
#   'moved',
#   'story',
#   'read',
#   'reports',
#   'online',
#   'johnson',
#   'not',
#   'actually',
#   'exist',
#   'saw',
#   'movie',
#   'confused',
#   'feelings',
#   'robin',
#   'williams',
#   'brilliantly',
#   'portrayed',
#   'resurfaced',
#   'mind',
#   'br',
#   'br',
#   'toni',
#   'collette',
#   'probably',
#   'gives',
#   'best',
#   'dramatic',
#   'performance',
#   'too',
#   'ultimately',
#   'sociopathic',
#   'caretaker',
#   'role',
#   'far',
#   'cry',
#   'movies',
#   'like',
#   'little',
#   'miss',
#   'sunshine',
#   'times',
#   'looked',
#   'camera',
#   'thought',
#   'staring',
#   'right',
#   'takes',
#   'good',
#   'actress',
#   'play',
#   'sort',
#   'role',
#   'understated',
#   'well',
#   'reviewed',
#   'role',
#   'makes',
#   'toni',
#   'collette',
#   'probably',
#   'best',
#   'actresses',
#   'generation',
#   'not',
#   'nominated',
#   'academy',
#   'award',
#   'incredible',
#   'least',
#   'woman',
#   'world',
#   'like',
#   'scary',
#   'too',
#   'br',
#   'br',
#   'good',
#   'dark',
#   'film',
#   'highly',
#   'recommend',
#   'prepared',
#   'unsettled',
#   'movie',
#   'leaves',
#   'strange',
#   'feeling',
#   'end'],
#  ['film',
#   'bad',
#   'no',
#   'way',
#   'story',
#   'weak',
#   'outdated',
#   'especially',
#   'country',
#   'don',
#   'think',
#   'people',
#   'know',
#   'walker',
#   'care',
#   'felt',
#   'watching',
#   'movie',
#   'subject',
#   'not',
#   'believable',
#   'year',
#   'set',
#   'dc',
#   'think',
#   'rang',
#   'true',
#   'watched',
#   'too',
#   'applause',
#   'low',
#   'quick',
#   'end',
#   'didn',
#   'stay',
#   'qa',
#   'br',
#   'br',
#   'don',
#   'think',
#   'schrader',
#   'thought',
#   'film',
#   'ahead',
#   'time',
#   'scenes',
#   'cut',
#   'short',
#   'never',
#   'finished',
#   'didn',
#   'know',
#   'finish',
#   'jumped',
#   'scene',
#   'try',
#   'figure',
#   'guess',
#   'going',
#   'didn',
#   'woody',
#   'carter',
#   'private',
#   'life',
#   'boyfriend',
#   'artistic',
#   'male',
#   'bondage',
#   'torture',
#   'pictures',
#   'iraq',
#   'prisons',
#   'thinking',
#   'think',
#   'poor',
#   'attempt',
#   'trying',
#   'create',
#   'dark',
#   'private',
#   'subculture',
#   'life',
#   'woody',
#   'character',
#   'car',
#   'didn',
#   'work',
#   'didn',
#   'sense',
#   'br',
#   'br',
#   'good',
#   'thing',
#   'film',
#   'woody',
#   'harrelson',
#   'played',
#   'character',
#   'car',
#   'flawlessly',
#   'great',
#   'sense',
#   'walker',
#   'like',
#   'years',
#   'ago',
#   'great',
#   'likely',
#   'never',
#   'recognized',
#   'br',
#   'br',
#   'lauren',
#   'lily',
#   'kristin',
#   'boring',
#   'br',
#   'br',
#   'don',
#   'painful',
#   'true',
#   'harrelson',
#   'fan'],
#  ['read',
#   'armistead',
#   'maupins',
#   'story',
#   'taken',
#   'human',
#   'drama',
#   'displayed',
#   'gabriel',
#   'no',
#   'cares',
#   'loves',
#   'said',
#   'given',
#   'film',
#   'version',
#   'excellent',
#   'story',
#   'expected',
#   'past',
#   'gloss',
#   'hollywood',
#   'br',
#   'br',
#   'writer',
#   'armistead',
#   'maupin',
#   'director',
#   'patrick',
#   'stettner',
#   'truly',
#   'succeeded',
#   'br',
#   'br',
#   'right',
#   'amount',
#   'restraint',
#   'robin',
#   'williams',
#   'captures',
#   'fragile',
#   'essence',
#   'gabriel',
#   'lets',
#   'struggle',
#   'issues',
#   'trust',
#   'personnel',
#   'life',
#   'jess',
#   'world',
#   'donna',
#   'br',
#   'br',
#   'introduced',
#   'players',
#   'drama',
#   'reminded',
#   'nothing',
#   'smallest',
#   'event',
#   'change',
#   'lives',
#   'irrevocably',
#   'request',
#   'review',
#   'book',
#   'written',
#   'young',
#   'man',
#   'turns',
#   'life',
#   'changing',
#   'event',
#   'helps',
#   'gabriel',
#   'find',
#   'strength',
#   'carry',
#   'forward',
#   'br',
#   'br',
#   'bad',
#   'people',
#   'avoid',
#   'film',
#   'average',
#   'american',
#   'probably',
#   'think',
#   'robin',
#   'williams',
#   'role',
#   'didn',
#   'work',
#   'movie',
#   'chance',
#   'robin',
#   'williams',
#   'touches',
#   'darkness',
#   'must',
#   'find',
#   'better',
#   'people',
#   'like',
#   'movie',
#   'hour',
#   'photo',
#   'stepped',
#   'up',
#   'actor',
#   'quality',
#   'piece',
#   'art',
#   'br',
#   'br',
#   'oh',
#   'forget',
#   'believe',
#   'bobby',
#   'cannavale',
#   'jess',
#   'steals',
#   'scene',
#   'leading',
#   'man',
#   'looks',
#   'screen',
#   'presence',
#   'hacks',
#   'opinion',
#   'carry',
#   'movie',
#   'right',
#   'br',
#   'br'],
#  ['film',
#   'giant',
#   'pant',
#   'load',
#   'paul',
#   'schrader',
#   'utterly',
#   'lost',
#   'bad',
#   'screenplay',
#   'directing',
#   'comatose',
#   'actually',
#   'sleepwalking',
#   'process',
#   'br',
#   'br',
#   'worst',
#   'woody',
#   'harrelson',
#   'ordinarily',
#   'like',
#   'properly',
#   'cast',
#   'plays',
#   'walker',
#   'homosexual',
#   'man',
#   'c',
#   'plays',
#   'social',
#   'companion',
#   'bored',
#   'wives',
#   'washington',
#   'elite',
#   'couldn',
#   'dimensional',
#   'cut',
#   'magazine',
#   'bounced',
#   'camera',
#   'popsicle',
#   'stick',
#   'southern',
#   'accent',
#   'rack',
#   'version',
#   'decrescendos',
#   'beginning',
#   'end',
#   'line',
#   'delivers',
#   'heat',
#   'humidity',
#   'south',
#   'draining',
#   'ounce',
#   'energy',
#   'monotonous',
#   'but',
#   'not',
#   'worst',
#   'accent',
#   'movie',
#   'boyfriend',
#   'played',
#   'moritz',
#   'bleibtreau',
#   'attempts',
#   'affect',
#   'kind',
#   'mid',
#   'east',
#   'accent',
#   'clumsy',
#   'barely',
#   'deliver',
#   'bad',
#   'lines',
#   'written',
#   'incapable',
#   'rolling',
#   'r',
#   'spite',
#   'fact',
#   'real',
#   'life',
#   'german',
#   'speaks',
#   'languages',
#   'italian',
#   'kind',
#   'good',
#   'reason',
#   'cast',
#   'don',
#   'ya',
#   'think',
#   'br',
#   'br',
#   'story',
#   'screenplay',
#   'directing',
#   'camera',
#   'work',
#   'performances',
#   'leads',
#   'movie',
#   'bad',
#   'beginning',
#   'end',
#   'tolerable',
#   'moments',
#   'film',
#   'came',
#   'supporting',
#   'actresses',
#   'lily',
#   'tomlin',
#   'lauren',
#   'bacall',
#   'kristin',
#   'scott',
#   'thomas',
#   'managed',
#   'movie',
#   'dignity',
#   'tact',
#   'fact',
#   'excellent',
#   'spite',
#   'trapped',
#   'bad',
#   'film',
#   'ufortunately',
#   'no',
#   'good',
#   'redeem',
#   'endless',
#   'series',
#   'flaws',
#   'like',
#   'actresses',
#   'watch',
#   'movie',
#   'not',
#   'worth',
#   'time'],
#  ['liked',
#   'film',
#   'action',
#   'scenes',
#   'interesting',
#   'tense',
#   'well',
#   'done',
#   'especially',
#   'liked',
#   'opening',
#   'scene',
#   'semi',
#   'truck',
#   'tense',
#   'action',
#   'scene',
#   'well',
#   'done',
#   'br',
#   'br',
#   'transitional',
#   'scenes',
#   'filmed',
#   'interesting',
#   'ways',
#   'time',
#   'lapse',
#   'photography',
#   'unusual',
#   'colors',
#   'interesting',
#   'angles',
#   'film',
#   'funny',
#   'parts',
#   'liked',
#   'evil',
#   'guy',
#   'portrayed',
#   'too',
#   'film'],
#  ['plot',
#   'descent',
#   'actually',
#   'called',
#   'plot',
#   'noteworthy',
#   'events',
#   'near',
#   'beginning',
#   'end',
#   'events',
#   'up',
#   'maybe',
#   'total',
#   'movie',
#   'time',
#   'mean',
#   'basically',
#   'director',
#   'desperate',
#   'effort',
#   'fill',
#   'minutes',
#   'like',
#   'disturbing',
#   'movies',
#   'like',
#   'dark',
#   'movies',
#   'don',
#   'troubled',
#   'gritty',
#   'scenes',
#   'but',
#   'expect',
#   'sit',
#   'minutes',
#   'hazy',
#   'dark',
#   'literally',
#   'scenes',
#   'no',
#   'storyline',
#   'thing',
#   'coming',
#   'rosario',
#   'dawson',
#   'favorite',
#   'actresses',
#   'completely',
#   'wasted',
#   'no',
#   'doesn',
#   'naked',
#   'not',
#   'nc',
#   'version',
#   'saw',
#   'br',
#   'br',
#   'couple',
#   'hours',
#   'throw',
#   'away',
#   'want',
#   'watch',
#   'descent',
#   'nap',
#   'instead',
#   'probably',
#   'interesting',
#   'dreams'],
#  ['illnesses',
#   'born',
#   'mind',
#   'man',
#   'given',
#   'life',
#   'modern',
#   'times',
#   'constant',
#   'vigilance',
#   'accrued',
#   'information',
#   'realm',
#   'pyschosis',
#   'kept',
#   'psychologists',
#   'counselors',
#   'psychiatrists',
#   'busy',
#   'work',
#   'decades',
#   'occasionally',
#   'mental',
#   'phenomenon',
#   'discover',
#   'no',
#   'knowledge',
#   'remedy',
#   'existence',
#   'premise',
#   'film',
#   'entitled',
#   'night',
#   'listner',
#   'tells',
#   'story',
#   'popular',
#   'radio',
#   'host',
#   'called',
#   'gabriel',
#   'noon',
#   'robin',
#   'williams',
#   'spends',
#   'evenings',
#   'enthralling',
#   'audiences',
#   'vivid',
#   'stories',
#   'gay',
#   'lifestyles',
#   'losing',
#   'authentic',
#   'veneer',
#   'causes',
#   'noon',
#   'admit',
#   'no',
#   'longer',
#   'feeling',
#   'abandoned',
#   'lover',
#   'jess',
#   'bobby',
#   'cannavale',
#   'best',
#   'friend',
#   'joe',
#   'morton',
#   'seeks',
#   'shelter',
#   'deepening',
#   'despair',
#   'isolation',
#   'mysterious',
#   'voice',
#   'night',
#   'asks',
#   'help',
#   'noon',
#   'needs',
#   'feel',
#   'useful',
#   'reaches',
#   'desperate',
#   'voice',
#   'belongs',
#   'year',
#   'old',
#   'boy',
#   'called',
#   'peter',
#   'rory',
#   'culkin',
#   'reading',
#   'boy',
#   'harrowing',
#   'manuscript',
#   'depicts',
#   'early',
#   'life',
#   'sexual',
#   'abuse',
#   'hands',
#   'brutal',
#   'parents',
#   'noon',
#   'captivated',
#   'wants',
#   'help',
#   'however',
#   'things',
#   'not',
#   'noon',
#   'soon',
#   'finds',
#   'en',
#   'wrapped',
#   'elusive',
#   'bizarre',
#   'tale',
#   'torn',
#   'right',
#   'medical',
#   'nightmare',
#   'movie',
#   'pure',
#   'robin',
#   'williams',
#   'not',
#   'toni',
#   'collette',
#   'plays',
#   'donna',
#   'logand',
#   'sandra',
#   'oh',
#   'anna',
#   'john',
#   'cullum',
#   'pop',
#   'comical',
#   'instead',
#   'prove',
#   'william',
#   'performances'],
#  ['plot',
#   'not',
#   'worth',
#   'discussion',
#   'hints',
#   'corruption',
#   'murder',
#   'power',
#   'rest',
#   'thriller',
#   'related',
#   'topics',
#   'characters',
#   'interesting',
#   'not',
#   'realistic',
#   'but',
#   'interesting',
#   'nevertheless',
#   'br',
#   'br',
#   'development',
#   'slow',
#   'like',
#   'tea',
#   'drinking',
#   'ceremony',
#   'visuals',
#   'not',
#   'stunning',
#   'but',
#   'good',
#   'ease',
#   'eye',
#   'strain',
#   'good',
#   'movie',
#   'watch',
#   'dinner',
#   'going',
#   'bed',
#   'nothing',
#   'shocking',
#   'too',
#   'nothing',
#   'overexciting',
#   'movie',
#   'sitcom',
#   'style',
#   'br',
#   'br',
#   'liked',
#   'woody',
#   'excellent',
#   'performance',
#   'fight',
#   'plot',
#   'inadequacy',
#   'job',
#   'pretty',
#   'good',
#   'rest',
#   'bearable',
#   'predictable',
#   'watchable',
#   'better',
#   'tv',
#   'shows'],
#  ['enjoyed',
#   'night',
#   'listener',
#   'better',
#   'movies',
#   'summer',
#   'br',
#   'br',
#   'robin',
#   'williams',
#   'gives',
#   'best',
#   'performances',
#   'fact',
#   'entire',
#   'cast',
#   'good',
#   'played',
#   'right',
#   'notes',
#   'characters',
#   'not',
#   'too',
#   'not',
#   'too',
#   'little',
#   'sandra',
#   'oh',
#   'adds',
#   'wonderful',
#   'comic',
#   'touch',
#   'toni',
#   'collette',
#   'great',
#   'mom',
#   'never',
#   'goes',
#   'top',
#   'believable',
#   'br',
#   'br',
#   'short',
#   'movie',
#   'hour',
#   'half',
#   'noticed',
#   'general',
#   'release',
#   'version',
#   'minutes',
#   'shorter',
#   'sundance',
#   'version',
#   'wonder',
#   'disturbing',
#   'images',
#   'cut',
#   'movie',
#   'br',
#   'br',
#   'director',
#   'told',
#   'story',
#   'straightforward',
#   'fashion',
#   'refreshing',
#   'change',
#   'directors',
#   'days',
#   'think',
#   'job',
#   'impress',
#   'audience',
#   'tell',
#   'story',
#   'tell',
#   'well',
#   'br',
#   'br',
#   'not',
#   'sucker',
#   'punched',
#   'previews',
#   'ads',
#   'not',
#   'hitchcockian',
#   'thriller',
#   'night',
#   'listener',
#   'want',
#   'good',
#   'story',
#   'told',
#   'well',
#   'expecting',
#   'hitchcock',
#   'disappointed',
#   'br',
#   'br',
#   'complaint',
#   'movie',
#   'ending',
#   'director',
#   'left',
#   'little',
#   'audience',
#   'imagination',
#   'but',
#   'minor',
#   'quibble'],
#  ['film',
#   'male',
#   'escort',
#   'getting',
#   'involved',
#   'murder',
#   'investigation',
#   'happened',
#   'circle',
#   'powerful',
#   'men',
#   'wives',
#   'br',
#   'br',
#   'thought',
#   'walker',
#   'thrilling',
#   'engaging',
#   'but',
#   'wrong',
#   'pacing',
#   'painfully',
#   'excruciatingly',
#   'slow',
#   'minutes',
#   'film',
#   'nothing',
#   'happens',
#   'seriously',
#   'hour',
#   'condensed',
#   'minutes',
#   'slow',
#   'br',
#   'br',
#   'fact',
#   'lacks',
#   'thrills',
#   'action',
#   'scenes',
#   'aggravates',
#   'boredom',
#   'almost',
#   'shocking',
#   'argument',
#   'scenes',
#   'plain',
#   'devoid',
#   'emotion',
#   'maybe',
#   'stiff',
#   'upper',
#   'lip',
#   'higher',
#   'social',
#   'class',
#   'br',
#   'br',
#   'sad',
#   'walker',
#   'boring',
#   'mess',
#   'despite',
#   'strong',
#   'cast',
#   'blame',
#   'poor',
#   'plot',
#   'worse',
#   'pacing'],
#  ['night',
#   'listener',
#   'probably',
#   'not',
#   'william',
#   'best',
#   'roles',
#   'but',
#   'makes',
#   'interesting',
#   'character',
#   'somewhat',
#   'odd',
#   'but',
#   'different',
#   'movie',
#   'guarantee',
#   'never',
#   'seen',
#   'kind',
#   'movie',
#   'people',
#   'maybe',
#   'won',
#   'like',
#   'slow',
#   'pacing',
#   'movie',
#   'but',
#   'think',
#   'great',
#   'plus',
#   'movie',
#   'definitely',
#   'top',
#   'movies',
#   'come',
#   'year',
#   'intriguing',
#   'performance',
#   'movie',
#   'great',
#   'content',
#   'dramatic',
#   'feeling',
#   'no',
#   'americanized',
#   'movie',
#   'neither',
#   'predictable',
#   'movie',
#   'feel',
#   'movie',
#   'secrets',
#   'hard',
#   'time',
#   'determine',
#   'outcome',
#   'no',
#   'excellent',
#   'movie',
#   'but',
#   'hell',
#   'damn',
#   'good',
#   'original',
#   'movie'],
#  ['movie',
#   'must',
#   'line',
#   'boring',
#   'movie',
#   'years',
#   'not',
#   'woody',
#   'harrison',
#   'save',
#   'movie',
#   'sinking',
#   'bottom',
#   'br',
#   'br',
#   'murder',
#   'movie',
#   'supposed',
#   'point',
#   'interest',
#   'movie',
#   'but',
#   'not',
#   'nothing',
#   'interest',
#   'cast',
#   'not',
#   'bad',
#   'but',
#   'script',
#   'plain',
#   'awful',
#   'sat',
#   'utter',
#   'amazement',
#   'movie',
#   'thinking',
#   'earth',
#   'find',
#   'movie',
#   'entertaining',
#   'br',
#   'br',
#   'producers',
#   'movie',
#   'clever',
#   'boring',
#   'movie',
#   'but',
#   'hid',
#   'well',
#   'names',
#   'good',
#   'actors',
#   'actresses',
#   'cast',
#   'people',
#   'blockbuster',
#   'probably',
#   'movie',
#   'think',
#   'woody',
#   'harrison',
#   'kristin',
#   'scott',
#   'thomas',
#   'willem',
#   'dafoe',
#   'must',
#   'good',
#   'rent',
#   'movie',
#   'boy',
#   'horrible',
#   'time',
#   'br',
#   'br',
#   'like',
#   'getting',
#   'ripped',
#   'rent',
#   'movie',
#   'people',
#   'actually',
#   'enjoyed',
#   'movie',
#   'but',
#   'like',
#   'watch',
#   'movie',
#   'meaning'],
#  ['like',
#   'previous',
#   'commenters',
#   'said',
#   'foundations',
#   'great',
#   'movie',
#   'but',
#   'happened',
#   'way',
#   'delivery',
#   'waste',
#   'collette',
#   'performance',
#   'eerie',
#   'williams',
#   'believable',
#   'kept',
#   'waiting',
#   'better',
#   'don',
#   'think',
#   'bad',
#   'editing',
#   'needed',
#   'director',
#   'film',
#   'came',
#   'canadian',
#   'movie',
#   'like',
#   'few',
#   'seasons',
#   'x',
#   'files',
#   'not',
#   'cheap',
#   'hokey',
#   'needed',
#   'little',
#   'suspense',
#   'makes',
#   'jump',
#   'seat',
#   'movie',
#   'reached',
#   'moment',
#   'faded',
#   'away',
#   'kind',
#   'like',
#   'false',
#   'climax',
#   'too',
#   'suspenseful',
#   'taken',
#   'away',
#   'reality',
#   'story',
#   'but',
#   'thought',
#   'reached',
#   'gabriel',
#   'hospital',
#   'looking',
#   'boy',
#   'movie',
#   'needs',
#   'director',
#   'cut',
#   'tries',
#   'fix',
#   'problems'],
#  ['worn',
#   'plot',
#   'man',
#   'takes',
#   'rap',
#   'woman',
#   'murder',
#   'case',
#   'equally',
#   'worn',
#   'plot',
#   'outsider',
#   'inside',
#   'eventually',
#   'shut',
#   'br',
#   'br',
#   'outstanding',
#   'case',
#   'think',
#   'film',
#   'rise',
#   'hackneyed',
#   'origins',
#   'but',
#   'scene',
#   'scene',
#   'drones',
#   'no',
#   'change',
#   'intensity',
#   'no',
#   'character',
#   'arcs',
#   'inexplicable',
#   'behavior',
#   'br',
#   'br',
#   'homosexuality',
#   'theme',
#   'completely',
#   'unnecessary',
#   'hand',
#   'completely',
#   'unexplored',
#   'included',
#   'titillate',
#   'viewers',
#   'hollywood',
#   'learn',
#   'gay',
#   'characters',
#   'not',
#   'automatically',
#   'compelling',
#   'picture',
#   'br',
#   'br',
#   'regrettably',
#   'dreadful',
#   'movie',
#   'lauren',
#   'bacall',
#   'pick',
#   'good',
#   'expected',
#   'better',
#   'kristin',
#   'scott',
#   'thomas',
#   'definitely',
#   'miss'],
#  ['night',
#   'listener',
#   'held',
#   'attention',
#   'robin',
#   'williams',
#   'shining',
#   'new',
#   'york',
#   'city',
#   'radio',
#   'host',
#   'enamored',
#   'friendship',
#   'year',
#   'old',
#   'boy',
#   'rory',
#   'culkin',
#   'ill',
#   'williams',
#   'never',
#   'met',
#   'boy',
#   'person',
#   'contact',
#   'talking',
#   'telephone',
#   'however',
#   'williams',
#   'ex',
#   'boyfriend',
#   'nice',
#   'job',
#   'bobby',
#   'cannavale',
#   'raises',
#   'doubt',
#   'boy',
#   'prompts',
#   'williams',
#   'arrange',
#   'meeting',
#   'person',
#   'follows',
#   'makes',
#   'permanent',
#   'impact',
#   'williams',
#   'way',
#   'not',
#   'expect',
#   'leave',
#   'toni',
#   'collette',
#   'stars',
#   'br',
#   'br',
#   'enjoyed',
#   'film',
#   'toni',
#   'collette',
#   'giving',
#   'memorable',
#   'portrayal',
#   'culkin',
#   'adoptive',
#   'mother',
#   'sandra',
#   'oh',
#   'starred',
#   'williams',
#   'friend',
#   'night',
#   'listener',
#   'inspired',
#   'actual',
#   'events',
#   'somber',
#   'almost',
#   'creepy',
#   'silence',
#   'times',
#   'predictable',
#   'no',
#   'thanks',
#   'reviews',
#   'read',
#   'seeing',
#   'movie',
#   'logic',
#   'but',
#   'liked',
#   'anyway',
#   'enjoy',
#   'williams',
#   'roles',
#   'like',
#   'comedic',
#   'characters',
#   'added',
#   'bonus',
#   'recommended'],
#  ['saw',
#   'movie',
#   'drive',
#   'howard',
#   'duck',
#   'considered',
#   'worst',
#   'movie',
#   'seen',
#   'movie',
#   'tried',
#   'combine',
#   'genera',
#   'comedy',
#   'horror',
#   'teenage',
#   'angst',
#   'hot',
#   'rod',
#   'must',
#   'sired',
#   'mother',
#   'car',
#   'maybe',
#   'deserves',
#   'second',
#   'viewing',
#   'accurate',
#   'reflection',
#   'time'],
#  ['popular',
#   'radio',
#   'storyteller',
#   'gabriel',
#   'no',
#   'robin',
#   'williams',
#   'scraggy',
#   'speaking',
#   'hushed',
#   'hypnotic',
#   'tones',
#   'acquainted',
#   'friends',
#   'fourteen',
#   'year',
#   'old',
#   'boy',
#   'wisconsin',
#   'named',
#   'pete',
#   'logand',
#   'rory',
#   'culkin',
#   'written',
#   'book',
#   'detailing',
#   'sexual',
#   'abuse',
#   'parents',
#   'boot',
#   'pete',
#   'aids',
#   'compels',
#   'gabriel',
#   'partner',
#   'jess',
#   'bobby',
#   'cannavale',
#   'good',
#   'happens',
#   'survivor',
#   'hiv',
#   'br',
#   'br',
#   'acquaints',
#   'pete',
#   'guardian',
#   'woman',
#   'named',
#   'donna',
#   'toni',
#   'collette',
#   'brilliant',
#   'gabriel',
#   'decides',
#   'wants',
#   'meet',
#   'talk',
#   'person',
#   'goes',
#   'wisconsin',
#   'discovers',
#   'secrets',
#   'naturally',
#   'not',
#   'prepared',
#   'find',
#   'br',
#   'br',
#   'based',
#   'real',
#   'events',
#   'happened',
#   'armistead',
#   'maupin',
#   'co',
#   'wrote',
#   'screenplay',
#   'terry',
#   'anderson',
#   'directed',
#   'patrick',
#   'stetner',
#   'film',
#   'moves',
#   'lot',
#   'faster',
#   'min',
#   'maybe',
#   'few',
#   'minutes',
#   'longer',
#   'think',
#   'movie',
#   'genre',
#   'run',
#   'good',
#   'keeps',
#   'action',
#   'storyline',
#   'lean',
#   'clear',
#   'bad',
#   'leaves',
#   'holes',
#   'plot',
#   'doesn',
#   'sew',
#   'up',
#   'plot',
#   'openings',
#   'story',
#   'not',
#   'great',
#   'detail',
#   'except',
#   'not',
#   'familiar',
#   'mr',
#   'maupin',
#   'works',
#   'personal',
#   'story',
#   'feel',
#   'little',
#   'bit',
#   'loop',
#   'performances',
#   'williams',
#   'loved',
#   'heard',
#   'narration',
#   'personally',
#   'collette',
#   'cannavale',
#   'culkin',
#   'supporting',
#   'cast',
#   'waitress',
#   'restaurant',
#   'collete',
#   'donna',
#   'frequents',
#   'great',
#   'job',
#   'small',
#   'top',
#   'notch',
#   'mood',
#   'established',
#   'chilly',
#   'lonely',
#   'dark',
#   'exteriors',
#   'wisconsin',
#   'new',
#   'york',
#   'terrific',
#   'framing',
#   'story',
#   'ends',
#   'don',
#   'tie',
#   'particularly',
#   'well',
#   'but',
#   'compelling',
#   'story',
#   'stick'],
#  ['ghost',
#   'dragstrip',
#   'hollow',
#   'typical',
#   'teens',
#   'turmoil',
#   'movie',
#   'not',
#   'horror',
#   'science',
#   'fiction',
#   'movie',
#   'plot',
#   'concerns',
#   'group',
#   'teens',
#   'kicked',
#   'hot',
#   'rod',
#   'club',
#   'cannot',
#   'meet',
#   'rent',
#   'kicked',
#   'decide',
#   'try',
#   'old',
#   'haunted',
#   'house',
#   'saving',
#   'grace',
#   'film',
#   'ghost',
#   'paul',
#   'blaisdell',
#   'creature',
#   'suit',
#   'turns',
#   'work',
#   'movie',
#   'monster',
#   'played',
#   'blaisdell'],
#  ['thing',
#   'recommend',
#   'film',
#   'intriguing',
#   'premise',
#   'certainly',
#   'draws',
#   'audience',
#   'mystery',
#   'film',
#   'hints',
#   'dark',
#   'lurking',
#   'however',
#   'not',
#   'tension',
#   'williams',
#   'mild',
#   'mannered',
#   'portrayal',
#   'doesn',
#   'makes',
#   'relate',
#   'obsession',
#   'boy',
#   'br',
#   'br',
#   'collete',
#   'fares',
#   'better',
#   'woman',
#   'true',
#   'nature',
#   'intentions',
#   'not',
#   'clear',
#   'production',
#   'felt',
#   'rushed',
#   'holes',
#   'apparent',
#   'certainly',
#   'feels',
#   'like',
#   'preview',
#   'complete',
#   'better',
#   'effort',
#   'book',
#   'probably',
#   'better',
#   'br',
#   'br',
#   'thing',
#   'certain',
#   'taupin',
#   'must',
#   'written',
#   'truly',
#   'good',
#   'inspired',
#   'least',
#   'commendable',
#   'effort'],
#  ['ghost',
#   'dragstrip',
#   'hollow',
#   'movies',
#   'hot',
#   'rodding',
#   'teens',
#   'encountering',
#   'supernatural',
#   'case',
#   'teens',
#   'pay',
#   'rent',
#   'hangout',
#   'evicted',
#   'decide',
#   'apparently',
#   'haunted',
#   'house',
#   'guessed',
#   'arrive',
#   'weird',
#   'things',
#   'start',
#   'happening',
#   'twist',
#   'end',
#   'br',
#   'br',
#   'nothing',
#   'movie',
#   'haven',
#   'seen',
#   'movies',
#   'but',
#   'nice',
#   'entertainment',
#   'nonetheless',
#   'favorite',
#   'character',
#   'foul',
#   'mouthed',
#   'parrot',
#   'well',
#   'let',
#   'rephrase',
#   'didn',
#   'talk',
#   'like',
#   'character',
#   'quentin',
#   'tarantino',
#   'movie',
#   'but',
#   'said',
#   'things',
#   'don',
#   'expect',
#   'bird',
#   'movie',
#   'pure',
#   'hokum',
#   'but',
#   'harmless'],
#  ['absolutely',
#   'loved',
#   'film',
#   'not',
# ...
#   'actually',
#   'truly',
#   'enjoyed',
#   'yes',
#   'saw',
#   'load',
#   'drunk',
#   'stoned',
#   'buddies',
#   'bits',
#   'funny',
#   'sad',
#   'kind',
#   'way',
#   'but',
#   'rest',
#   'audience',
#   'entertaining',
#   'parts',
#   'said',
#   'group',
#   'buddies',
#   'throwing',
#   'popcorn',
#   'abusive',
#   'insults',
#   'screen',
#   'watched',
#   'up',
#   'few',
#   'laughs',
#   'guy',
#   'few',
#   'beers',
#   'preparation',
#   'chuckle',
#   'away',
#   'film',
#   'expected',
#   'crapness',
#   'got',
#   'crapness',
#   'plenty',
#   'but',
#   'not',
#   'chuckles',
#   'doesn',
#   'qualify',
#   'bad',
#   'good',
#   'movie',
#   'plain',
#   'bad',
#   'bad',
#   'look',
#   'away',
#   'spoilerphobic',
#   'movie',
#   'starts',
#   'guy',
#   'beating',
#   'guy',
#   'death',
#   'ok',
#   'few',
#   'minutes',
#   'late',
#   'not',
#   'sure',
#   'but',
#   'think',
#   'grasped',
#   'guy',
#   'bit',
#   'badass',
#   'don',
#   'want',
#   'mess',
#   'message',
#   'ingenious',
#   'scene',
#   'oh',
#   'guy',
#   'witnesses',
#   'ultra',
#   'evil',
#   'bad',
#   'guy',
#   'wussy',
#   'but',
#   'cute',
#   'apparently',
#   'good',
#   'guy',
#   'cue',
#   'hero',
#   'big',
#   'sam',
#   'steps',
#   'scene',
#   'usual',
#   'fashion',
#   'saving',
#   'good',
#   'guy',
#   'usual',
#   'inane',
#   'way',
#   'poor',
#   'action',
#   'films',
#   'accomplish',
#   'e',
#   'hero',
#   'immune',
#   'bullets',
#   'falls',
#   'clumsily',
#   'cue',
#   'plot',
#   'hole',
#   'bloody',
#   'hell',
#   'sammy',
#   'know',
#   'guy',
#   'watched',
#   'murder',
#   'answers',
#   'plot',
#   'hole',
#   'related',
#   'questions',
#   'explained',
#   'minutes',
#   'got',
#   'cinema',
#   'but',
#   'doubt',
#   'fact',
#   'going',
#   'stop',
#   'poking',
#   'holes',
#   'plot',
#   'right',
#   'lest',
#   'turn',
#   'movie',
#   'resembling',
#   'swiss',
#   'cheese',
#   'know',
#   'good',
#   'cheese',
#   'plot',
#   'generous',
#   'word',
#   'use',
#   'good',
#   'guy',
#   'must',
#   'la',
#   'evil',
#   'guy',
#   'didn',
#   'hero',
#   'sam',
#   'stands',
#   'cue',
#   'scenery',
#   'vomit',
#   'inducing',
#   'hour',
#   'passenger',
#   'plane',
#   'said',
#   'no',
#   'poking',
#   'plot',
#   'holes',
#   'leave',
#   'passenger',
#   'plane',
#   'vital',
#   'ingredient',
#   'up',
#   'missing',
#   'gem',
#   'movie',
#   'makes',
#   'snakes',
#   'yay',
#   'oh',
#   'pause',
#   'introduction',
#   'obligatory',
#   'characters',
#   'lame',
#   'movie',
#   'must',
#   'hot',
#   'horny',
#   'couple',
#   'guess',
#   'die',
#   'dead',
#   'snakes',
#   'appear',
#   'british',
#   'guy',
#   'pesky',
#   'brits',
#   'eh',
#   'cute',
#   'kids',
#   'jo',
#   'brand',
#   'americans',
#   'english',
#   'comic',
#   'famous',
#   'size',
#   'unattractiveness',
#   'met',
#   'cast',
#   'let',
#   'watch',
#   'die',
#   'except',
#   'course',
#   'cute',
#   'kids',
#   'don',
#   'expect',
#   'original',
#   'snake',
#   'bites',
#   'increasingly',
#   'hilarious',
#   'not',
#   'parts',
#   'body',
#   'use',
#   'imagination',
#   'film',
#   'makers',
#   'obviously',
#   'didn',
#   'use',
#   'br',
#   'br',
#   'film',
#   'wrapped',
#   'up',
#   'best',
#   'bit',
#   'ending',
#   'expected',
#   'happy',
#   'plane',
#   'lands',
#   'sight',
#   'starts',
#   'sucking',
#   'face',
#   'yep',
#   'ice',
#   'cool',
#   'sammy',
#   'included',
#   'but',
#   'wait',
#   'not',
#   'plane',
#   'guy',
#   'good',
#   'guy',
#   'but',
#   'gets',
#   'bitten',
#   'guessed',
#   'snake',
#   'things',
#   'clearly',
#   'hiding',
#   'mr',
#   'jackson',
#   'hair',
#   'time',
#   'managed',
#   'resist',
#   'air',
#   'pressure',
#   'trick',
#   'good',
#   'old',
#   'hero',
#   'employed',
#   'few',
#   'minutes',
#   'earlier',
#   'despite',
#   'ft',
#   'constrictor',
#   'ate',
#   'pesky',
#   'british',
#   'bugger',
#   'unable',
#   'sam',
#   'shoots',
#   'snake',
#   'fell',
#   'swoop',
#   'point',
#   'prayed',
#   'movie',
#   'needed',
#   'u',
#   'turn',
#   'reveal',
#   'hero',
#   'actually',
#   'traitor',
#   'sort',
#   'but',
#   'no',
#   'kind',
#   'icing',
#   'cake',
#   'way',
#   'but',
#   'stale',
#   'cheese',
#   'remember',
#   'revealed',
#   'climax',
#   'film',
#   'involving',
#   'bullet',
#   'proof',
#   'vest',
#   'think',
#   'audience',
#   'years',
#   'ago',
#   'let',
#   'impressed',
#   'ingenuity',
#   'but',
#   'well',
#   'summing',
#   'up',
#   'film',
#   'br',
#   'br',
#   'actually',
#   'not',
#   'done',
#   'sucked',
#   'face',
#   'uncle',
#   'sam',
#   'leading',
#   'actress',
#   'good',
#   'guy',
#   'tiffany',
#   'token',
#   'black',
#   'guy',
#   'token',
#   'white',
#   'girl',
#   'hot',
#   'couple',
#   'heart',
#   'warming',
#   'bout',
#   'necrophilia',
#   'time',
#   'good',
#   'guy',
#   'hero',
#   'bali',
#   'nope',
#   'wasn',
#   'exciting',
#   'exclamation',
#   'marks',
#   'represent',
#   'utter',
#   'joy',
#   'seeing',
#   'credits',
#   'roll',
#   'yes',
#   'final',
#   'shot',
#   'film',
#   'celebratory',
#   'surfing',
#   'trip',
#   'convey',
#   'message',
#   'bit',
#   'male',
#   'bonding',
#   'occurred',
#   'chance',
#   'morons',
#   'actually',
#   'enjoyed',
#   'movie',
#   'whoop',
#   'few',
#   'times',
#   'time',
#   'posted',
#   'movie',
#   'review',
#   'but',
#   'felt',
#   'strongly',
#   'somebody',
#   'must',
#   'speak',
#   'against',
#   'scourge',
#   'cinematography',
#   'like',
#   'planes',
#   'snakes',
#   'samuel',
#   'l',
#   'jackson',
#   'air',
#   'hostesses',
#   'bad',
#   'guys',
#   'surfing',
#   'dogs',
#   'bags',
#   'english',
#   'people',
#   'don',
#   'movie',
#   'pollute',
#   'opinion',
#   'far',
#   'never',
#   'want',
#   'come',
#   'contact',
#   'again',
#   'united',
#   'instead',
#   'good'],
#  ['never',
#   'heard',
#   'film',
#   'couple',
#   'weeks',
#   'ago',
#   'but',
#   'concept',
#   'interested',
#   'heard',
#   'american',
#   'man',
#   'meets',
#   'european',
#   'woman',
#   'night',
#   'europe',
#   'spend',
#   'night',
#   'talking',
#   'sparked',
#   'interest',
#   'but',
#   'never',
#   'expected',
#   'great',
#   'sunrise',
#   'masterpiece',
#   'romantic',
#   'films',
#   'record',
#   'surprise',
#   'completely',
#   'lacked',
#   'cynicism',
#   'impossible',
#   'talk',
#   'too',
#   'no',
#   'real',
#   'plot',
#   'speak',
#   'plenty',
#   'thoroughly',
#   'interesting',
#   'things',
#   'talk',
#   'sort',
#   'like',
#   'dinner',
#   'andre',
#   'conversation',
#   'but',
#   'not',
#   'conversation',
#   'matters',
#   'but',
#   'let'],
#  ['not',
#   'film',
#   'analyse',
#   'separately',
#   'production',
#   'audience',
#   'film',
#   'makers',
#   'extent',
#   'unprecedented',
#   'history',
#   'american',
#   'film',
#   'industry',
#   'felt',
#   'involved',
#   'viewing',
#   'like',
#   'watching',
#   'work',
#   'friend',
#   'possible',
#   'objective',
#   'movie',
#   'isn',
#   'nothing',
#   'disingenuous',
#   'film',
#   'maker',
#   'promotes',
#   'audience',
#   'friend',
#   'giving',
#   'naughty',
#   'treats',
#   'nannyish',
#   'critics',
#   'deny',
#   'look',
#   'prime',
#   'self',
#   'publicist',
#   'eli',
#   'roth',
#   'promising',
#   'gore',
#   'hounds',
#   'viscera',
#   'missing',
#   'literally',
#   'gutless',
#   'mainstream',
#   'horror',
#   'films',
#   'churn',
#   'watered',
#   'down',
#   'technically',
#   'incompetent',
#   'piece',
#   'work',
#   'like',
#   'hostel',
#   'br',
#   'br',
#   'david',
#   'r',
#   'ellis',
#   'not',
#   'spawned',
#   'monster',
#   'internet',
#   'response',
#   'film',
#   'but',
#   'understandably',
#   'quick',
#   'engage',
#   'took',
#   'carnival',
#   'huckster',
#   'school',
#   'film',
#   'making',
#   'new',
#   'level',
#   'getting',
#   'fans',
#   'build',
#   'eventually',
#   'buy',
#   'enthused',
#   'interactive',
#   'democratic',
#   'approach',
#   'film',
#   'making',
#   'missed',
#   'point',
#   'cynical',
#   'form',
#   'film',
#   'marketing',
#   'nothing',
#   'included',
#   'film',
#   'makers',
#   'know',
#   'fans',
#   'won',
#   'buy',
#   'old',
#   'suggestion',
#   'bums',
#   'seats',
#   'incorporated',
#   'fact',
#   'pitch',
#   'title',
#   'tells',
#   'need',
#   'know',
#   'br',
#   'br',
#   'isn',
#   'evolution',
#   'focus',
#   'group',
#   'approach',
#   'individual',
#   'creativity',
#   'talent',
#   'craft',
#   'ideas',
#   'sacrificed',
#   'inane',
#   'chatter',
#   'masses',
#   'critical',
#   'commonplace',
#   'focus',
#   'groups',
#   'test',
#   'screenings',
#   'don',
#   'good',
#   'movies',
#   'should',
#   'preemptive',
#   'intervention',
#   'internet',
#   'enthusiasts',
#   'different',
#   'happen',
#   'film',
#   'fans',
#   'well',
#   'thank',
#   'god',
#   'not',
#   'seen',
#   'topless',
#   'woman',
#   'nipple',
#   'bitten',
#   'snake',
#   'br',
#   'br',
#   'yes',
#   'fun',
#   'movie',
#   'midnight',
#   'showing',
#   'fresh',
#   'pub',
#   'bucket',
#   'ice',
#   'cream',
#   'but',
#   'actually',
#   'relatively',
#   'little',
#   'film',
#   'lot',
#   'atmosphere',
#   'like',
#   'christmas',
#   'determined',
#   'fun',
#   'no',
#   'matter',
#   'laughter',
#   'but',
#   'don',
#   'know',
#   'film',
#   'film',
#   'film',
#   'calculated',
#   'meaningful',
#   'distinction',
#   'genuinely',
#   'good',
#   'aspects',
#   'film',
#   'samuel',
#   'l',
#   'jackson',
#   'gives',
#   'well',
#   'judged',
#   'performance',
#   'pure',
#   'self',
#   'parody',
#   'but',
#   'real',
#   'sense',
#   'pleasure',
#   'rachel',
#   'blanchard',
#   'lin',
#   'shaye',
#   'decent',
#   'limited',
#   'roles',
#   'inspired',
#   'moments',
#   'fate',
#   'lap',
#   'dog',
#   'genuinely',
#   'funny',
#   'black',
#   'comedy',
#   'rest',
#   'film',
#   'fails',
#   'emulate',
#   'br',
#   'br',
#   'stock',
#   'characters',
#   'expected',
#   'but',
#   'total',
#   'lack',
#   'suspense',
#   'isn',
#   'point',
#   'film',
#   'combines',
#   'great',
#   'phobias',
#   'no',
#   'creeping',
#   'menace',
#   'snake',
#   'jumps',
#   'moments',
#   'but',
#   'incredibly',
#   'badly',
#   'staged',
#   'annoying',
#   'british',
#   'man',
#   'gets',
#   'decent',
#   'pulpy',
#   'death',
#   'scene',
#   'killings',
#   'oddly',
#   'flat',
#   'demise',
#   'honeymoon',
#   'couple',
#   'instance',
#   'shamefully',
#   'botched',
#   'actors',
#   'fail',
#   'impression',
#   'shame',
#   'charismatic',
#   'actress',
#   'like',
#   'julianna',
#   'margulies',
#   'should',
#   'tired',
#   'tells',
#   'kids',
#   'close',
#   'eyes',
#   'pretend',
#   'turbulent',
#   'flight',
#   'roller',
#   'coaster',
#   'talking',
#   'audience',
#   'film',
#   'falls',
#   'far',
#   'short',
#   'br',
#   'br',
#   'worse',
#   'movies',
#   'but',
#   'better',
#   'reviewer',
#   'site',
#   'compared',
#   'film',
#   'lake',
#   'placid',
#   'apt',
#   'contrast',
#   'think',
#   'film',
#   'worked',
#   'magnificently',
#   'performances',
#   'excellent',
#   'jokes',
#   'funny',
#   'suspense',
#   'sequences',
#   'scary',
#   'wasn',
#   'devised',
#   'committee',
#   'characters',
#   'little',
#   'depth',
#   'shading',
#   'unexpected',
#   'bonus',
#   'don',
#   'need',
#   'post',
#   'pub',
#   'midnight',
#   'showing',
#   'good',
#   'time',
#   'film',
#   'br',
#   'br',
#   'film',
#   'time',
#   'fade',
#   'mere',
#   'footnote',
#   'film',
#   'history',
#   'sets',
#   'precedent',
#   'however',
#   'genuinely',
#   'worried',
#   'crossing',
#   'screens',
#   'couple',
#   'years',
#   'time',
#   'probability',
#   'nothing',
#   'come',
#   'perennial',
#   'popcorn',
#   'favourites',
#   'raiders',
#   'lost',
#   'ark',
#   'alien',
#   'halloween',
#   'course',
#   'star',
#   'wars',
#   'aren',
#   'produced',
#   'group',
#   'think',
#   'br',
#   'br',
#   'mean',
#   'time',
#   'tell',
#   'haven',
#   'half',
#   'got',
#   'craving',
#   'ingmar',
#   'bergman'],
#  ['criticisms',
#   'thread',
#   'pick',
#   'comparison',
#   'film',
#   'mortal',
#   'storm',
#   'casablanca',
#   'entitled',
#   'compare',
#   'films',
#   'choose',
#   'but',
#   'similarities',
#   'mortal',
#   'storm',
#   'watch',
#   'rhine',
#   'clearly',
#   'problems',
#   'refugees',
#   'threatened',
#   'nazi',
#   'juggernaut',
#   'main',
#   'comparative',
#   'point',
#   'brought',
#   'casablanca',
#   'unjust',
#   'treatment',
#   'humphrey',
#   'bogart',
#   'academy',
#   'motion',
#   'picture',
#   'arts',
#   'science',
#   'chose',
#   'paul',
#   'lukas',
#   'instead',
#   'best',
#   'actor',
#   'oscar',
#   'not',
#   'strike',
#   'totally',
#   'wrong',
#   'lukas',
#   'good',
#   'career',
#   'film',
#   'england',
#   'villain',
#   'lady',
#   'vanishes',
#   'performance',
#   'best',
#   'bogart',
#   'great',
#   'performances',
#   'rick',
#   'blaine',
#   'instance',
#   'ignored',
#   'sam',
#   'spade',
#   'maltese',
#   'falcon',
#   'roy',
#   'earle',
#   'high',
#   'sierra',
#   'years',
#   'earlier',
#   'rate',
#   'performances',
#   'not',
#   'oscar',
#   'greatest',
#   'performances',
#   'fred',
#   'c',
#   'dobbs',
#   'treasure',
#   'sierra',
#   'madres',
#   'writer',
#   'murder',
#   'suspect',
#   'lonely',
#   'place',
#   'captain',
#   'philip',
#   'francis',
#   'queeg',
#   'caine',
#   'mutiny',
#   'afterward',
#   'got',
#   'charley',
#   'african',
#   'queen',
#   'think',
#   'bogie',
#   'should',
#   'got',
#   'role',
#   'dobbs',
#   'but',
#   'not',
#   'happen',
#   'but',
#   'lukas',
#   'lucky',
#   'got',
#   'defining',
#   'performance',
#   'lesser',
#   'career',
#   'few',
#   'claim',
#   'br',
#   'br',
#   'film',
#   'look',
#   'watch',
#   'rhine',
#   'based',
#   'play',
#   'script',
#   'hellman',
#   'searching',
#   'wind',
#   'look',
#   'america',
#   'spirit',
#   'isolationism',
#   'searching',
#   'wind',
#   'looking',
#   'inter',
#   'war',
#   'period',
#   'watch',
#   'rhine',
#   'set',
#   'years',
#   'proceeding',
#   'entry',
#   'world',
#   'war',
#   'ii',
#   'deals',
#   'few',
#   'weeks',
#   'time',
#   'better',
#   'constructed',
#   'play',
#   'meaningful',
#   'impact',
#   'br',
#   'br',
#   'film',
#   'good',
#   'performances',
#   'led',
#   'lukas',
#   'exhausted',
#   'but',
#   'determined',
#   'anti',
#   'nazi',
#   'fighter',
#   'courier',
#   'davis',
#   'loyal',
#   'wife',
#   'wisely',
#   'keeping',
#   'character',
#   'low',
#   'keyed',
#   'possible',
#   'lukas',
#   'center',
#   'play',
#   'activities',
#   'coulouris',
#   'selfish',
#   'conniving',
#   'but',
#   'ultimately',
#   'foolish',
#   'ineffective',
#   'teck',
#   'lucille',
#   'watson',
#   'mother',
#   'davis',
#   'geraldine',
#   'fitzgerald',
#   'coulouris',
#   'wiser',
#   'sadder',
#   'fed',
#   'up',
#   'wife',
#   'kurt',
#   'katch',
#   'delivers',
#   'devastating',
#   'critique',
#   'local',
#   'embassy',
#   'gestapo',
#   'chief',
#   'coulouris',
#   'deal',
#   'nazis',
#   'dialog',
#   'bite',
#   'says',
#   'true',
#   'moments',
#   'near',
#   'poetry',
#   'witness',
#   'scene',
#   'end',
#   'coulouris',
#   'left',
#   'lukas',
#   'davis',
#   'says',
#   'new',
#   'world',
#   'left',
#   'scene',
#   'old',
#   'world',
#   'hellman',
#   'write',
#   'well',
#   'times',
#   'br',
#   'br',
#   'given',
#   'strength',
#   'film',
#   'script',
#   'performances',
#   'rate',
#   'film',
#   'highly',
#   'among',
#   'world',
#   'war',
#   'ii',
#   'films'],
#  ['raising',
#   'victor',
#   'vargas',
#   'light',
#   'family',
#   'movies',
#   'watch',
#   'n',
#   'times',
#   'crossword',
#   'puzzle',
#   'time',
#   'want',
#   'kitchen',
#   'taco',
#   'corona',
#   'don',
#   'pause',
#   'dvd',
#   'let',
#   'roll',
#   'cause',
#   'won',
#   'missing',
#   'important',
#   'no',
#   'twists',
#   'turns',
#   'tension',
#   'not',
#   'ethnic',
#   'movie',
#   'movie',
#   'poor',
#   'struggling',
#   'immigrant',
#   'family',
#   'happens',
#   'latino',
#   'ethnic',
#   'group',
#   'little',
#   'difference',
#   'seen',
#   'zillion',
#   'times',
#   'plug',
#   'jewish',
#   'family',
#   'italian',
#   'family',
#   'black',
#   'family',
#   'irish',
#   'family',
#   'accents',
#   'names',
#   'different',
#   'vargas',
#   'family',
#   'named',
#   'bush',
#   'clinton',
#   'presbyterians',
#   'movie',
#   'total',
#   'snooze',
#   'br',
#   'br',
#   'funny',
#   'critics',
#   'couldn',
#   'locale',
#   'straight',
#   'said',
#   'spanish',
#   'harlem',
#   'bronx',
#   'brooklyn',
#   'life',
#   'long',
#   'new',
#   'yorker',
#   'vote',
#   'lower',
#   'east',
#   'family',
#   'never',
#   'met',
#   'up',
#   'except',
#   'latinos',
#   'lived',
#   'insulated',
#   'isolated',
#   'little',
#   'enclave',
#   'interaction',
#   'non',
#   'latinos',
#   'created',
#   'excitement',
#   'interest',
#   'tension',
#   'remember',
#   'west',
#   'story',
#   'br',
#   'br',
#   'oft',
#   'criticized',
#   'cinematography',
#   'don',
#   'know',
#   'tv',
#   'but',
#   'indoor',
#   'shots',
#   'looked',
#   'orange',
#   'apt',
#   'furniture',
#   'faces',
#   'orange',
#   'supposed',
#   'mean',
#   'apt',
#   'look',
#   'pretty',
#   'cramped',
#   'somebody',
#   'mentioned',
#   'old',
#   'apt',
#   'tenements',
#   'big',
#   'rooms',
#   'well',
#   'maybe',
#   'years',
#   'ago',
#   'landlords',
#   'done',
#   'break',
#   'up',
#   'big',
#   'apt',
#   'small',
#   'ones',
#   'squeeze',
#   'immigrants',
#   'br',
#   'br',
#   'annoying',
#   'thing',
#   'second',
#   'family',
#   'movie',
#   'seen',
#   'criticized',
#   'week',
#   'featured',
#   'teenage',
#   'boy',
#   'jerking',
#   'private',
#   'sex',
#   'act',
#   'necessary',
#   'watch',
#   'spare',
#   'up',
#   'directors',
#   'br',
#   'br',
#   'victor',
#   'vargas',
#   'pleasant',
#   'little',
#   'movie',
#   'nice',
#   'change',
#   'young',
#   'latino',
#   'actors',
#   'given',
#   'break',
#   'chance',
#   'talents',
#   'but',
#   'writers',
#   'let',
#   'down',
#   'giving',
#   'flat',
#   'unspectacular',
#   'script',
#   'work',
#   'enjoy',
#   'but',
#   'fingers',
#   'near',
#   'fast',
#   'forward',
#   'button'],
#  ...]

# %% [markdown]
# # Pipeline
#
# 지금까지의 과정을 one process to after the other로 변경해 data flow가 흐른 뒤 원하는 결과를 얻을 수 있도록 하는 과정
#
# 중간에 필요한 process가 있다면 쉽게 add or delete가 가능함.
#
# spacy에서 이 기능을 제공함.
#
# 일단 함수로 차근차근 다시 만들어보자는 취지인 듯함. 워낙 인도발음이 세서 뭐라는지 모르겠음

# %%
def load_data():
    reviewsFile = open("./Hands-on-NLP-with-PyTorch-master/data/reviews.txt",'r')
    reviews = list(map(lambda x:x[:-1],reviewsFile.readlines()))
    reviewsFile.close()

    labelsFile = open("./Hands-on-NLP-with-PyTorch-master/data/labels.txt",'r')
    labels = list(map(lambda x:x[:-1],labelsFile.readlines()))
    labelsFile.close()
    
    return reviews,labels

# %%
reviews, labels = load_data()

# %%
from nltk.tokenize import RegexpTokenizer
tokenizer = RegexpTokenizer("\w+\'?\w+|\w+")

from nltk.corpus import stopwords
stop_words = stopwords.words('english')

from spacy.lang.en.stop_words import STOP_WORDS

exceptionStopWords = {
    'again',
    'against',
    'ain',
    'almost',
    'among',
    'amongst',
    'amount',
    'anyhow',
    'anyway',
    'aren',
    "aren't",
    'below',
    'bottom',
    'but',
    'cannot',
    'couldn',
    "couldn't",
    'didn',
    "didn't",
    'doesn',
    "doesn't",
    'don',
    "don't",
    'done',
    'down',
    'except',
    'few',
    'hadn',
    "hadn't",
    'hasn',
    "hasn't",
    'haven',
    "haven't",
    'however',
    'isn',
    "isn't",
    'least',
    'mightn',
    "mightn't",
    'move',
    'much',
    'must',
    'mustn',
    "mustn't",
    'needn',
    "needn't",
    'neither',
    'never',
    'nevertheless',
    'no',
    'nobody',
    'none',
    'noone',
    'nor',
    'not',
    'nothing',
    'should',
    "should've",
    'shouldn',
    "shouldn't",
    'too',
    'top',
    'up',
    'wasn',
    "wasn't",
    'well',
    'weren',
    "weren't",
    'won',
    "won't",
    'wouldn',
    "wouldn't",
}

stop_words = set(stop_words).union(STOP_WORDS)

final_stop_words = stop_words-exceptionStopWords

import spacy
nlp = spacy.load("en",disable=['parser', 'tagger', 'ner'])

def make_token(review):
    return tokenizer.tokenize(str(review))

def remove_stopwords(review):
    return [token for token in review if token not in final_stop_words]

def lemmatization(review):
    lemma_result = []
    
    for words in review:
        doc = nlp(words)
        for token in doc:
            lemma_result.append(token.lemma_)
    return lemma_result

def pipeline(review):
    review = make_token(review)
    review = remove_stopwords(review)
    return lemmatization(review)

# %%time
reviews = list(map(lambda review: pipeline(review),reviews))
